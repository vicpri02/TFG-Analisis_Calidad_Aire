# %%
import pandas as pd
import numpy as np 
from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

años = ["2018", "2019", "2020", "2021", "2022", "2023", "2024"]
dataframes = {}
for a in años:
    dataframes[a] = pd.read_csv(filepath_or_buffer=f'./{a}.csv', 
                    delimiter=';', 
                    decimal=',',
                    header=0)

# %%
#magnitudes = [7, 8, 10, 11, 12, 14, 22]
magnitudes = [8, 14, 10]
for a in dataframes:
    df = dataframes[a]
    dataframes[a] = df[df.magnitud.isin(magnitudes)]
   
dataframes["2022"]
# Out:
#        provincia  municipio  estacion  magnitud  punto_muestreo   ano  mes  \
# 3             28        102         1         8    28102001_8_8  2022    1
# 4             28        102         1        10  28102001_10_49  2022    1
# 6             28        102         1        14   28102001_14_6  2022    1
# 8             28        120         1         8    28120001_8_8  2022    1
# 10            28        120         1        10  28120001_10_49  2022    1
# ...          ...        ...       ...       ...             ...   ...  ...
# 58282         28          9         1         8    28009001_8_8  2022   12
# 58285         28          9         1        14   28009001_14_6  2022   12
# 58289         28         92         5         8    28092005_8_8  2022   12
# 58290         28         92         5        10  28092005_10_49  2022   12
# 58292         28         92         5        14   28092005_14_6  2022   12
#
#        dia   h01 v01  ...   h20 v20   h21 v21   h22 v22   h23 v23   h24 v24
# 3        1   8.0   V  ...  16.0   V  15.0   V  12.0   V  10.0   V   9.0   V
# 4        1   5.0   V  ...   9.0   V   7.0   V   6.0   V   5.0   V   6.0   V
# 6        1  59.0   V  ...  49.0   V  50.0   V  52.0   V  54.0   V  56.0   V
# 8        1   1.0   V  ...   1.0   V   1.0   V   1.0   V   1.0   V   1.0   V
# 10       1   1.0   V  ...   1.0   V   2.0   V   2.0   V   1.0   V   1.0   V
# ...    ...   ...  ..  ...   ...  ..   ...  ..   ...  ..   ...  ..   ...  ..
# 58282   31  12.0   V  ...  39.0   V  22.0   V  18.0   V  19.0   V  13.0   V
# 58285   31  50.0   V  ...  34.0   V  36.0   V  48.0   V  39.0   V  47.0   V
# 58289   31  19.0   V  ...  89.0   V  83.0   V  78.0   V  73.0   V  71.0   V
# 58290   31  23.0   V  ...  46.0   V  50.0   V  47.0   V  44.0   V  54.0   V
# 58292   31  37.0   V  ...   3.0   V   3.0   V   2.0   V   2.0   V   4.0   V
#
# [24348 rows x 56 columns]

# %%
#est = [(5, 2), (6, 4), (13, 2), (14, 2), (16, 1), (45, 2), (49, 3),
#       (58, 4), (65, 14), (67, 1), (74, 7), (80, 3), (92, 5), (102, 1),
#       (120, 1), (123, 2), (133, 2), (148, 4), (171, 1)]

est = [(74,7), (148,4), (67,1)]
#est = [(74,7)]

for a in dataframes:
    df = dataframes[a]
    dataframes[a] = df[df.apply(lambda row: (row['municipio'], row['estacion']) in est, axis=1)]

#dataframes["2020"]

# %% [markdown]
# Quitamos las columnas innecesarias

# %%
for a in dataframes:
    df = dataframes[a]
    dataframes[a] = df.drop(['provincia', 'punto_muestreo'], axis = 1)

dataframes["2020"]
# Out:
#        municipio  estacion  magnitud   ano  mes  dia   h01 v01   h02 v02  ...  \
# 34           148         4         8  2020    1    1  42.0   V  41.0   V  ...
# 36           148         4        10  2020    1    1   NaN   N   NaN   N  ...
# 38           148         4        14  2020    1    1   5.0   V   4.0   V  ...
# 128           67         1         8  2020    1    1  27.0   V  28.0   V  ...
# 129           67         1        10  2020    1    1  25.0   V  41.0   V  ...
# ...          ...       ...       ...   ...  ...  ...   ...  ..   ...  ..  ...
# 58529         67         1        10  2020   12   31  22.0   V  23.0   V  ...
# 58531         67         1        14  2020   12   31  33.0   V  34.0   V  ...
# 58538         74         7         8  2020   12   31  18.0   V  11.0   V  ...
# 58540         74         7        10  2020   12   31  13.0   V   8.0   V  ...
# 58542         74         7        14  2020   12   31  50.0   V  55.0   V  ...
#
#         h20 v20   h21 v21   h22 v22   h23 v23   h24 v24
# 34     83.0   V  53.0   V  55.0   V  48.0   V  39.0   V
# 36      NaN   N   NaN   N   NaN   N   NaN   N   NaN   N
# 38      6.0   V   5.0   V   5.0   V   4.0   V   4.0   V
# 128    37.0   V  33.0   V  32.0   V  29.0   V  24.0   V
# 129    42.0   V  38.0   V  37.0   V  33.0   V  32.0   V
# ...     ...  ..   ...  ..   ...  ..   ...  ..   ...  ..
# 58529  35.0   V  21.0   V  15.0   V   7.0   V  14.0   V
# 58531  37.0   V  41.0   V  70.0   V  69.0   V  60.0   V
# 58538  15.0   V  13.0   V   9.0   V   9.0   V  15.0   V
# 58540   5.0   V   5.0   V   5.0   V   3.0   V   3.0   V
# 58542  46.0   V  45.0   V  48.0   V  49.0   V  62.0   V
#
# [3294 rows x 54 columns]

# %% [markdown]
# Limpiamos la base de datos

# %%
str_val = [f'v{str(i).zfill(2)}' for i in range(1, 25)]
str_horas = [f'h{str(i).zfill(2)}' for i in range(1, 25)]

#Sustituimos los valores no válidos y Nan por la media de la concentración para cada hora y magnitud 
def limpia_df(df):
    for m in magnitudes:
        for i in range(0,24): 
            val = str_val[i]
            hora = str_horas[i]
            #Cambiamos valores no válidos con magnitud m 
            df_val = df[(df[val] == "V") & (df["magnitud"] == m)]

            ind_v = df.index[(df[val] == 'N') & (df["magnitud"] == m)].tolist()

            df.loc[ind_v, val] = "V"
            df.loc[ind_v, hora] = df_val[hora].mean()
            #Sustituimos los valores Nan 
            ind_nan = df.index[(df[hora] == np.NaN) & (df["magnitud"] == m)].tolist() 
            df.loc[ind_nan, hora] = df_val[hora].mean()
    

for a in años:
    df = dataframes[a]
    limpia_df(df)

# %%
#Transformamos los dataframes para que tengan la forma municipio, estacion, magnitud, año, mes, dia 
#y normalizamos los datos. 
def transf_df(df):  
    df_unico = pd.melt(df, id_vars=['municipio', 'estacion', 'magnitud', 'ano', 'mes', 'dia'],
                      value_vars=str_horas, var_name='hora', value_name='valor')
    df_unico['hora_num'] = df_unico['hora'].str[1:].astype(int)
    df_unico.drop("hora", axis = 1, inplace=True)

    return df_unico

for a in años:
    df = dataframes[a]
    dataframes[a] = transf_df(df)

# %%
#Concatenamos los datos de cada año en un solo Dataframe    
l_df = []
for a in años:
    df = dataframes[a]
    l_df.append(df)

df_total = pd.concat(l_df, ignore_index=True)


#Creamos una columna para cada contaminante 
df_total = df_total.pivot_table(index=['municipio', 'estacion', 'ano', 'mes', 'dia', 'hora_num'],
                         columns='magnitud',
                         values='valor') 

df_total.columns = [f'{col}' for col in df_total.columns]
df_total = df_total.reset_index()

#Ponemos como índice la fecha 
df_total = df_total.rename(columns={'ano': 'year', 'mes': 'month', 'dia': 'day'})
df_total['fecha'] = pd.to_datetime(df_total[['year', 'month', 'day']]) + pd.to_timedelta(df_total['hora_num'] - 1, unit='h')
#df_total = df_total.sort_values(by='fecha')
df_total = df_total.rename(columns={'year': 'ano', 'month': 'mes', 'day': 'dia'})
df_total = df_total.set_index('fecha')
df_total.sort_index(inplace=True)

# %%
df_total
# Out:
#                      municipio  estacion   ano  mes  dia  hora_num     8  \
# fecha
# 2018-01-01 00:00:00         67         1  2018    1    1         1   2.0
# 2018-01-01 00:00:00         74         7  2018    1    1         1  71.0
# 2018-01-01 00:00:00        148         4  2018    1    1         1  43.0
# 2018-01-01 01:00:00         67         1  2018    1    1         2   5.0
# 2018-01-01 01:00:00         74         7  2018    1    1         2  32.0
# ...                        ...       ...   ...  ...  ...       ...   ...
# 2024-05-31 22:00:00         67         1  2024    5   31        23  10.0
# 2024-05-31 22:00:00         74         7  2024    5   31        23  12.0
# 2024-05-31 23:00:00         74         7  2024    5   31        24   8.0
# 2024-05-31 23:00:00         67         1  2024    5   31        24   6.0
# 2024-05-31 23:00:00        148         4  2024    5   31        24   3.0
#
#                        10    14
# fecha
# 2018-01-01 00:00:00   1.0  86.0
# 2018-01-01 00:00:00  28.0  12.0
# 2018-01-01 00:00:00  61.0  31.0
# 2018-01-01 01:00:00   1.0  80.0
# 2018-01-01 01:00:00  30.0  48.0
# ...                   ...   ...
# 2024-05-31 22:00:00  19.0  71.0
# 2024-05-31 22:00:00   8.0  81.0
# 2024-05-31 23:00:00   8.0  79.0
# 2024-05-31 23:00:00  20.0  78.0
# 2024-05-31 23:00:00  13.0  83.0
#
# [168696 rows x 9 columns]

# %%
# Creamos un diccionario con los DataFrames de cada ciudad 
df_dict = {}

for municipio, estacion in est:
    df_estacion = df_total[(df_total['municipio'] == municipio) & (df_total['estacion'] == estacion)]
    
    df_key = f'({municipio},{estacion})'
    df_dict[df_key] = df_estacion 

# Mostrar dataframes 
for key, value in df_dict.items():
    print(f"DataFrame para {key}:")
    print(value, "\n")
# Out:
# DataFrame para (74,7):
#                      municipio  estacion   ano  mes  dia  hora_num     8  \
# fecha
# 2018-01-01 00:00:00         74         7  2018    1    1         1  71.0
# 2018-01-01 01:00:00         74         7  2018    1    1         2  32.0
# 2018-01-01 02:00:00         74         7  2018    1    1         3  29.0
# 2018-01-01 03:00:00         74         7  2018    1    1         4  14.0
# 2018-01-01 04:00:00         74         7  2018    1    1         5  13.0
# ...                        ...       ...   ...  ...  ...       ...   ...
# 2024-05-31 19:00:00         74         7  2024    5   31        20  21.0
# 2024-05-31 20:00:00         74         7  2024    5   31        21  23.0
# 2024-05-31 21:00:00         74         7  2024    5   31        22  17.0
# 2024-05-31 22:00:00         74         7  2024    5   31        23  12.0
# 2024-05-31 23:00:00         74         7  2024    5   31        24   8.0
#
#                        10    14
# fecha
# 2018-01-01 00:00:00  28.0  12.0
# 2018-01-01 01:00:00  30.0  48.0
# 2018-01-01 02:00:00  21.0  50.0
# 2018-01-01 03:00:00  15.0  55.0
# 2018-01-01 04:00:00  15.0  49.0
# ...                   ...   ...
# 2024-05-31 19:00:00   7.0  87.0
# 2024-05-31 20:00:00   9.0  82.0
# 2024-05-31 21:00:00   9.0  82.0
# 2024-05-31 22:00:00   8.0  81.0
# 2024-05-31 23:00:00   8.0  79.0
#
# [56232 rows x 9 columns]
#
# DataFrame para (148,4):
#                      municipio  estacion   ano  mes  dia  hora_num     8  \
# fecha
# 2018-01-01 00:00:00        148         4  2018    1    1         1  43.0
# 2018-01-01 01:00:00        148         4  2018    1    1         2  37.0
# 2018-01-01 02:00:00        148         4  2018    1    1         3  28.0
# 2018-01-01 03:00:00        148         4  2018    1    1         4  21.0
# 2018-01-01 04:00:00        148         4  2018    1    1         5  13.0
# ...                        ...       ...   ...  ...  ...       ...   ...
# 2024-05-31 19:00:00        148         4  2024    5   31        20  11.0
# 2024-05-31 20:00:00        148         4  2024    5   31        21  11.0
# 2024-05-31 21:00:00        148         4  2024    5   31        22   8.0
# 2024-05-31 22:00:00        148         4  2024    5   31        23   5.0
# 2024-05-31 23:00:00        148         4  2024    5   31        24   3.0
#
#                        10    14
# fecha
# 2018-01-01 00:00:00  61.0  31.0
# 2018-01-01 01:00:00  44.0  39.0
# 2018-01-01 02:00:00  36.0  48.0
# 2018-01-01 03:00:00  33.0  53.0
# 2018-01-01 04:00:00  21.0  55.0
# ...                   ...   ...
# 2024-05-31 19:00:00  11.0  95.0
# 2024-05-31 20:00:00   9.0  83.0
# 2024-05-31 21:00:00  11.0  84.0
# 2024-05-31 22:00:00  12.0  85.0
# 2024-05-31 23:00:00  13.0  83.0
#
# [56232 rows x 9 columns]
#
# DataFrame para (67,1):
#                      municipio  estacion   ano  mes  dia  hora_num     8  \
# fecha
# 2018-01-01 00:00:00         67         1  2018    1    1         1   2.0
# 2018-01-01 01:00:00         67         1  2018    1    1         2   5.0
# 2018-01-01 02:00:00         67         1  2018    1    1         3   5.0
# 2018-01-01 03:00:00         67         1  2018    1    1         4   2.0
# 2018-01-01 04:00:00         67         1  2018    1    1         5   4.0
# ...                        ...       ...   ...  ...  ...       ...   ...
# 2024-05-31 19:00:00         67         1  2024    5   31        20   5.0
# 2024-05-31 20:00:00         67         1  2024    5   31        21   9.0
# 2024-05-31 21:00:00         67         1  2024    5   31        22   5.0
# 2024-05-31 22:00:00         67         1  2024    5   31        23  10.0
# 2024-05-31 23:00:00         67         1  2024    5   31        24   6.0
#
#                        10     14
# fecha
# 2018-01-01 00:00:00   1.0   86.0
# 2018-01-01 01:00:00   1.0   80.0
# 2018-01-01 02:00:00   5.0   75.0
# 2018-01-01 03:00:00   3.0   87.0
# 2018-01-01 04:00:00   4.0   73.0
# ...                   ...    ...
# 2024-05-31 19:00:00  12.0  103.0
# 2024-05-31 20:00:00  15.0   86.0
# 2024-05-31 21:00:00  19.0   87.0
# 2024-05-31 22:00:00  19.0   71.0
# 2024-05-31 23:00:00  20.0   78.0
#
# [56232 rows x 9 columns]

# %% [markdown]
# Versión 2 del diccionario de dataframes, donde cada fila contiene el valor diario calculado como la media de las concentraciones de las 24 horas.

# %%
# Creamos un diccionario con los DataFrames de cada ciudad 
df_dict = {}

for municipio, estacion in est:
    df_estacion = df_total[(df_total['municipio'] == municipio) & (df_total['estacion'] == estacion)]
    df_est_diario = df_estacion.resample('D').mean()
    df_key = f'({municipio},{estacion})'
    df_dict[df_key] = df_est_diario


# Mostrar dataframes 
for key, value in df_dict.items():
    print(f"DataFrame para {key}:")
    print(value, "\n")

# %%
correlation_matrix = df_total.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Matriz de Correlación')
plt.show()

# %%
df_total
df_total = df_total.rename(columns={'ano': 'year', 'mes': 'month', 'dia': 'day'})
df_total['fecha'] = pd.to_datetime(df_total[['year', 'month', 'day']]) + pd.to_timedelta(df_total['hora_num'] - 1, unit='h')
#df_total = df_total.sort_values(by='fecha')
df_total = df_total.set_index('fecha')
df_total.sort_index(inplace=True)

# Crear una nueva columna 'seconds' que contiene los segundos desde el inicio del día
#df_total['seconds'] = df_total['fecha'].dt.hour * 3600 + df_total['fecha'].dt.minute * 60 + df_total['fecha'].dt.second
date_time = pd.to_datetime(df_total.pop('fecha'))
timestamp_s = date_time.map(pd.Timestamp.timestamp)
df_total['segundos'] = timestamp_s
df_total['seg_nor'] = df_total['segundos'] - df_total['segundos'].iloc[0]
df_total.drop(columns=["year", "month","day","hora_num","segundos"],inplace=True)

# %%
df_total
# Out:
#         municipio  estacion   ano  mes  dia  hora_num     8    10    14
# 0              67         1  2018    1    1         1   2.0   1.0  86.0
# 1              67         1  2018    1    1         2   5.0   1.0  80.0
# 2              67         1  2018    1    1         3   5.0   5.0  75.0
# 3              67         1  2018    1    1         4   2.0   3.0  87.0
# 4              67         1  2018    1    1         5   4.0   4.0  73.0
# ...           ...       ...   ...  ...  ...       ...   ...   ...   ...
# 168691        148         4  2024    5   31        20  11.0  11.0  95.0
# 168692        148         4  2024    5   31        21  11.0   9.0  83.0
# 168693        148         4  2024    5   31        22   8.0  11.0  84.0
# 168694        148         4  2024    5   31        23   5.0  12.0  85.0
# 168695        148         4  2024    5   31        24   3.0  13.0  83.0
#
# [168696 rows x 9 columns]

# %% [markdown]
# Calucalmos y visualizamos la matriz de correlacion

# %%
correlation_matrix = df_total.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Matriz de Correlación')
plt.show()

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Dividimos los datos en datos de entrenamiento y prueba

# %%
train_dataset = df_total.sample(frac=0.8, random_state=0)
test_dataset = df_total.drop(train_dataset.index)

# %%
n = len(df_total)

train_dataset = df_total[0:int(n*0.8)]
test_dataset = df_total[int(n*0.8):]

# %% [markdown]
# Datos para predecir un contaminante contando los demás

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('14')
test_labels = test_features.pop('14')

# %%
train_dataset.describe().transpose()[['mean', 'std']]

# %% [markdown]
# Datos para predecir los tres contaminantes

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

col = ['8', '10', '14']
train_labels = train_features['14'].copy()
test_labels = test_features['14'].copy()

train_features = train_features.drop(columns=col)
test_features=test_features.drop(columns=col)

# %%
df_total
train_features
# Out:
#         municipio  estacion   ano  mes  dia  hora_num
# 0              67         1  2018    1    1         1
# 1              67         1  2018    1    1         2
# 2              67         1  2018    1    1         3
# 3              67         1  2018    1    1         4
# 4              67         1  2018    1    1         5
# ...           ...       ...   ...  ...  ...       ...
# 134951        148         4  2020    7   25        24
# 134952        148         4  2020    7   26         1
# 134953        148         4  2020    7   26         2
# 134954        148         4  2020    7   26         3
# 134955        148         4  2020    7   26         4
#
# [134956 rows x 6 columns]

# %%
df_leg = df_dict['(74,7)']
df_leg.describe().transpose()[['mean', 'std']]
# Out:
#                   mean        std
# municipio    74.000000   0.000000
# estacion      7.000000   0.000000
# year       2020.726846   1.862692
# month         6.295775   3.464381
# day          15.725566   8.798250
# hora_num     12.500000   6.922248
# 8            32.142587  26.230249
# 10           21.111264  19.522238
# 14           50.920473  33.732141

# %% [markdown]
# Capa de normalizacion N(0,1)

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(np.array(train_features))
print(normalizer.mean.numpy())
# Out:
# [[  83.41628      4.        2020.411        6.2383294   15.711492
#     12.499703 ]]

# %%
linear_model = tf.keras.Sequential([
    normalizer,
    layers.Dense(64, activation='tanh'),
    layers.Dense(100, activation="tanh"),
    layers.Dense(128, activation='tanh'),
    layers.Dense(64, activation='tanh'),
    layers.Dense(30, activation = 'tanh'),
    layers.Dense(1)
])
linear_model.predict(train_features[:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 linear_model = tf.keras.Sequential([
# ----> 2     normalizer,
#       3     layers.Dense(64, activation='tanh'),
#       4     layers.Dense(100, activation="tanh"),
#       5     layers.Dense(128, activation='tanh'),
#       6     layers.Dense(64, activation='tanh'),
#       7     layers.Dense(30, activation = 'tanh'),
#       8     layers.Dense(1)
#       9 ])
#      10 linear_model.predict(train_features[:10])
#
# NameError: name 'normalizer' is not defined

# %%
linear_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='mean_squared_error',
    metrics=['mean_absolute_error', 'mean_squared_error'])
history = linear_model.fit(
    train_features,
    train_labels,
    epochs=150,
    batch_size=64,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.1)
# Out:
# Epoch 1/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 3720.7891 - mean_absolute_error: 51.1793 - mean_squared_error: 3720.7891 - val_loss: 6408.6465 - val_mean_absolute_error: 71.9944 - val_mean_squared_error: 6405.6865
# Epoch 2/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 3122.4734 - mean_absolute_error: 46.3171 - mean_squared_error: 3122.4734 - val_loss: 7168.8843 - val_mean_absolute_error: 77.0926 - val_mean_squared_error: 7165.7461
# Epoch 3/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 2787.9458 - mean_absolute_error: 43.4783 - mean_squared_error: 2787.9458 - val_loss: 7951.4502 - val_mean_absolute_error: 82.0100 - val_mean_squared_error: 7948.1401
# Epoch 4/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 2515.5002 - mean_absolute_error: 40.9943 - mean_squared_error: 2515.5002 - val_loss: 8754.4336 - val_mean_absolute_error: 86.7668 - val_mean_squared_error: 8750.9570
# Epoch 5/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 2297.9805 - mean_absolute_error: 38.9139 - mean_squared_error: 2297.9805 - val_loss: 9559.2031 - val_mean_absolute_error: 91.2856 - val_mean_squared_error: 9555.5684
# Epoch 6/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 2144.2485 - mean_absolute_error: 37.2476 - mean_squared_error: 2144.2488 - val_loss: 10343.0234 - val_mean_absolute_error: 95.4817 - val_mean_squared_error: 10339.2422
# Epoch 7/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 2034.7478 - mean_absolute_error: 35.9730 - mean_squared_error: 2034.7478 - val_loss: 11048.6406 - val_mean_absolute_error: 99.1073 - val_mean_squared_error: 11044.7324
# Epoch 8/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1977.2522 - mean_absolute_error: 35.1329 - mean_squared_error: 1977.2522 - val_loss: 11598.8896 - val_mean_absolute_error: 101.8450 - val_mean_squared_error: 11594.8857
# Epoch 9/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1959.3999 - mean_absolute_error: 34.7406 - mean_squared_error: 1959.4000 - val_loss: 11900.0879 - val_mean_absolute_error: 103.3127 - val_mean_squared_error: 11896.0322
# Epoch 10/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1947.5720 - mean_absolute_error: 34.4410 - mean_squared_error: 1947.5720 - val_loss: 12013.4229 - val_mean_absolute_error: 103.8597 - val_mean_squared_error: 12009.3477
# Epoch 11/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1926.9133 - mean_absolute_error: 34.2689 - mean_squared_error: 1926.9135 - val_loss: 2559.3171 - val_mean_absolute_error: 41.6967 - val_mean_squared_error: 2557.6057
# Epoch 12/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1095.6902 - mean_absolute_error: 27.2665 - mean_squared_error: 1095.6902 - val_loss: 1329.4841 - val_mean_absolute_error: 30.1663 - val_mean_squared_error: 1328.6530
# Epoch 13/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 894.5162 - mean_absolute_error: 24.5915 - mean_squared_error: 894.5162 - val_loss: 1169.5664 - val_mean_absolute_error: 28.1836 - val_mean_squared_error: 1168.8744
# Epoch 14/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 792.5134 - mean_absolute_error: 23.0469 - mean_squared_error: 792.5134 - val_loss: 1070.5928 - val_mean_absolute_error: 26.9375 - val_mean_squared_error: 1069.9192
# Epoch 15/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 706.4615 - mean_absolute_error: 21.6716 - mean_squared_error: 706.4615 - val_loss: 913.0227 - val_mean_absolute_error: 24.8765 - val_mean_squared_error: 912.3972
# Epoch 16/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 629.7547 - mean_absolute_error: 20.4141 - mean_squared_error: 629.7547 - val_loss: 786.8756 - val_mean_absolute_error: 22.8436 - val_mean_squared_error: 786.3771
# Epoch 17/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 571.4099 - mean_absolute_error: 19.5180 - mean_squared_error: 571.4099 - val_loss: 707.9938 - val_mean_absolute_error: 21.7265 - val_mean_squared_error: 707.5963
# Epoch 18/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 535.9045 - mean_absolute_error: 18.8340 - mean_squared_error: 535.9045 - val_loss: 705.8777 - val_mean_absolute_error: 21.4480 - val_mean_squared_error: 705.5046
# Epoch 19/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 504.7385 - mean_absolute_error: 18.2948 - mean_squared_error: 504.7385 - val_loss: 663.6566 - val_mean_absolute_error: 20.7682 - val_mean_squared_error: 663.3344
# Epoch 20/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 486.0849 - mean_absolute_error: 17.9728 - mean_squared_error: 486.0849 - val_loss: 605.6662 - val_mean_absolute_error: 19.9101 - val_mean_squared_error: 605.4125
# Epoch 21/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 472.9986 - mean_absolute_error: 17.7389 - mean_squared_error: 472.9986 - val_loss: 599.8137 - val_mean_absolute_error: 19.7967 - val_mean_squared_error: 599.5875
# Epoch 22/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 464.3040 - mean_absolute_error: 17.5560 - mean_squared_error: 464.3040 - val_loss: 563.4056 - val_mean_absolute_error: 19.2061 - val_mean_squared_error: 563.2375
# Epoch 23/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 455.5455 - mean_absolute_error: 17.3844 - mean_squared_error: 455.5455 - val_loss: 559.3953 - val_mean_absolute_error: 19.1559 - val_mean_squared_error: 559.2396
# Epoch 24/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 449.2929 - mean_absolute_error: 17.2689 - mean_squared_error: 449.2929 - val_loss: 556.9897 - val_mean_absolute_error: 19.0839 - val_mean_squared_error: 556.8616
# Epoch 25/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 448.6033 - mean_absolute_error: 17.2444 - mean_squared_error: 448.6033 - val_loss: 561.4581 - val_mean_absolute_error: 19.1700 - val_mean_squared_error: 561.3188
# Epoch 26/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 446.8801 - mean_absolute_error: 17.2172 - mean_squared_error: 446.8801 - val_loss: 559.3138 - val_mean_absolute_error: 19.0773 - val_mean_squared_error: 559.1863
# Epoch 27/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 443.1911 - mean_absolute_error: 17.1452 - mean_squared_error: 443.1911 - val_loss: 562.5574 - val_mean_absolute_error: 19.1842 - val_mean_squared_error: 562.4388
# Epoch 28/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 439.0396 - mean_absolute_error: 17.0809 - mean_squared_error: 439.0396 - val_loss: 592.1841 - val_mean_absolute_error: 19.6046 - val_mean_squared_error: 592.0549
# Epoch 29/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 438.6714 - mean_absolute_error: 17.0750 - mean_squared_error: 438.6714 - val_loss: 554.7264 - val_mean_absolute_error: 19.0278 - val_mean_squared_error: 554.6299
# Epoch 30/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 440.8635 - mean_absolute_error: 17.1148 - mean_squared_error: 440.8635 - val_loss: 544.8665 - val_mean_absolute_error: 18.8330 - val_mean_squared_error: 544.8041
# Epoch 31/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 436.4806 - mean_absolute_error: 17.0165 - mean_squared_error: 436.4806 - val_loss: 539.9220 - val_mean_absolute_error: 18.7983 - val_mean_squared_error: 539.8553
# Epoch 32/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 433.4483 - mean_absolute_error: 16.9364 - mean_squared_error: 433.4483 - val_loss: 547.3503 - val_mean_absolute_error: 18.9318 - val_mean_squared_error: 547.2709
# Epoch 33/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 433.2523 - mean_absolute_error: 16.9448 - mean_squared_error: 433.2523 - val_loss: 565.4822 - val_mean_absolute_error: 19.2450 - val_mean_squared_error: 565.3959
# Epoch 34/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 431.6259 - mean_absolute_error: 16.9088 - mean_squared_error: 431.6259 - val_loss: 530.3279 - val_mean_absolute_error: 18.5645 - val_mean_squared_error: 530.2891
# Epoch 35/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 433.5000 - mean_absolute_error: 16.9605 - mean_squared_error: 433.5000 - val_loss: 568.7811 - val_mean_absolute_error: 19.1828 - val_mean_squared_error: 568.7351
# Epoch 36/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 430.7805 - mean_absolute_error: 16.8846 - mean_squared_error: 430.7805 - val_loss: 557.0083 - val_mean_absolute_error: 18.9820 - val_mean_squared_error: 556.9547
# Epoch 37/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 425.2340 - mean_absolute_error: 16.7636 - mean_squared_error: 425.2340 - val_loss: 549.3738 - val_mean_absolute_error: 18.7886 - val_mean_squared_error: 549.3356
# Epoch 38/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 425.5266 - mean_absolute_error: 16.7477 - mean_squared_error: 425.5266 - val_loss: 566.9836 - val_mean_absolute_error: 19.1367 - val_mean_squared_error: 566.9368
# Epoch 39/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 424.7873 - mean_absolute_error: 16.7488 - mean_squared_error: 424.7873 - val_loss: 559.0673 - val_mean_absolute_error: 19.0166 - val_mean_squared_error: 559.0390
# Epoch 40/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 425.1016 - mean_absolute_error: 16.7575 - mean_squared_error: 425.1016 - val_loss: 558.2131 - val_mean_absolute_error: 19.0265 - val_mean_squared_error: 558.1893
# Epoch 41/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 422.6555 - mean_absolute_error: 16.7063 - mean_squared_error: 422.6555 - val_loss: 521.1089 - val_mean_absolute_error: 18.3559 - val_mean_squared_error: 521.1179
# Epoch 42/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 420.4135 - mean_absolute_error: 16.6325 - mean_squared_error: 420.4135 - val_loss: 522.1162 - val_mean_absolute_error: 18.4519 - val_mean_squared_error: 522.1317
# Epoch 43/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 416.4380 - mean_absolute_error: 16.5648 - mean_squared_error: 416.4380 - val_loss: 522.0916 - val_mean_absolute_error: 18.3901 - val_mean_squared_error: 522.1047
# Epoch 44/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 418.0682 - mean_absolute_error: 16.5941 - mean_squared_error: 418.0682 - val_loss: 556.7119 - val_mean_absolute_error: 18.8931 - val_mean_squared_error: 556.7068
# Epoch 45/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 419.1532 - mean_absolute_error: 16.5875 - mean_squared_error: 419.1532 - val_loss: 540.7531 - val_mean_absolute_error: 18.6757 - val_mean_squared_error: 540.7332
# Epoch 46/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 412.2613 - mean_absolute_error: 16.4235 - mean_squared_error: 412.2613 - val_loss: 544.2055 - val_mean_absolute_error: 18.7368 - val_mean_squared_error: 544.2013
# Epoch 47/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 412.7050 - mean_absolute_error: 16.4729 - mean_squared_error: 412.7050 - val_loss: 583.3839 - val_mean_absolute_error: 19.3303 - val_mean_squared_error: 583.3399
# Epoch 48/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 409.9429 - mean_absolute_error: 16.3716 - mean_squared_error: 409.9429 - val_loss: 543.4305 - val_mean_absolute_error: 18.7187 - val_mean_squared_error: 543.4227
# Epoch 49/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 410.5255 - mean_absolute_error: 16.3725 - mean_squared_error: 410.5255 - val_loss: 570.0375 - val_mean_absolute_error: 19.1542 - val_mean_squared_error: 570.0084
# Epoch 50/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 411.7696 - mean_absolute_error: 16.4254 - mean_squared_error: 411.7696 - val_loss: 578.2834 - val_mean_absolute_error: 19.3143 - val_mean_squared_error: 578.2340
# Epoch 51/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 410.2193 - mean_absolute_error: 16.3885 - mean_squared_error: 410.2193 - val_loss: 548.7216 - val_mean_absolute_error: 18.8147 - val_mean_squared_error: 548.7332
# Epoch 52/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 405.6161 - mean_absolute_error: 16.2587 - mean_squared_error: 405.6161 - val_loss: 598.7228 - val_mean_absolute_error: 19.5220 - val_mean_squared_error: 598.6871
# Epoch 53/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 404.8750 - mean_absolute_error: 16.2564 - mean_squared_error: 404.8751 - val_loss: 597.9560 - val_mean_absolute_error: 19.5183 - val_mean_squared_error: 597.9459
# Epoch 54/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 401.4539 - mean_absolute_error: 16.1879 - mean_squared_error: 401.4539 - val_loss: 602.0965 - val_mean_absolute_error: 19.5376 - val_mean_squared_error: 602.1086
# Epoch 55/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 402.9262 - mean_absolute_error: 16.2091 - mean_squared_error: 402.9262 - val_loss: 593.2620 - val_mean_absolute_error: 19.4330 - val_mean_squared_error: 593.2501
# Epoch 56/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 399.9259 - mean_absolute_error: 16.1462 - mean_squared_error: 399.9259 - val_loss: 603.7657 - val_mean_absolute_error: 19.6091 - val_mean_squared_error: 603.7325
# Epoch 57/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 398.0862 - mean_absolute_error: 16.0993 - mean_squared_error: 398.0862 - val_loss: 588.5261 - val_mean_absolute_error: 19.3898 - val_mean_squared_error: 588.5235
# Epoch 58/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 396.8413 - mean_absolute_error: 16.0426 - mean_squared_error: 396.8413 - val_loss: 581.5814 - val_mean_absolute_error: 19.2944 - val_mean_squared_error: 581.5875
# Epoch 59/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 394.6233 - mean_absolute_error: 16.0040 - mean_squared_error: 394.6233 - val_loss: 651.3250 - val_mean_absolute_error: 20.3336 - val_mean_squared_error: 651.3102
# Epoch 60/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 396.0501 - mean_absolute_error: 16.0609 - mean_squared_error: 396.0501 - val_loss: 627.5371 - val_mean_absolute_error: 20.0844 - val_mean_squared_error: 627.5209
# Epoch 61/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 394.8162 - mean_absolute_error: 16.0048 - mean_squared_error: 394.8163 - val_loss: 635.5219 - val_mean_absolute_error: 20.0980 - val_mean_squared_error: 635.5369
# Epoch 62/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 394.4159 - mean_absolute_error: 16.0100 - mean_squared_error: 394.4159 - val_loss: 632.4882 - val_mean_absolute_error: 20.0474 - val_mean_squared_error: 632.5391
# Epoch 63/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 395.6173 - mean_absolute_error: 16.0162 - mean_squared_error: 395.6173 - val_loss: 694.1453 - val_mean_absolute_error: 20.9984 - val_mean_squared_error: 694.1429
# Epoch 64/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 391.9038 - mean_absolute_error: 15.9364 - mean_squared_error: 391.9038 - val_loss: 612.2955 - val_mean_absolute_error: 19.7119 - val_mean_squared_error: 612.3506
# Epoch 65/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 390.5461 - mean_absolute_error: 15.9073 - mean_squared_error: 390.5461 - val_loss: 624.5778 - val_mean_absolute_error: 19.8384 - val_mean_squared_error: 624.6525
# Epoch 66/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 387.7626 - mean_absolute_error: 15.8333 - mean_squared_error: 387.7626 - val_loss: 655.1822 - val_mean_absolute_error: 20.3206 - val_mean_squared_error: 655.2195
# Epoch 67/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 386.7275 - mean_absolute_error: 15.8061 - mean_squared_error: 386.7275 - val_loss: 667.8384 - val_mean_absolute_error: 20.5718 - val_mean_squared_error: 667.9130
# Epoch 68/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 385.0378 - mean_absolute_error: 15.7414 - mean_squared_error: 385.0378 - val_loss: 746.9442 - val_mean_absolute_error: 21.7892 - val_mean_squared_error: 746.9536
# Epoch 69/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 384.1798 - mean_absolute_error: 15.7270 - mean_squared_error: 384.1798 - val_loss: 727.3781 - val_mean_absolute_error: 21.4924 - val_mean_squared_error: 727.4327
# Epoch 70/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 382.1022 - mean_absolute_error: 15.7040 - mean_squared_error: 382.1023 - val_loss: 673.8576 - val_mean_absolute_error: 20.6508 - val_mean_squared_error: 673.9725
# Epoch 71/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 380.9339 - mean_absolute_error: 15.6651 - mean_squared_error: 380.9339 - val_loss: 659.8741 - val_mean_absolute_error: 20.5057 - val_mean_squared_error: 659.9506
# Epoch 72/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 381.2117 - mean_absolute_error: 15.6545 - mean_squared_error: 381.2117 - val_loss: 655.8869 - val_mean_absolute_error: 20.3245 - val_mean_squared_error: 655.9948
# Epoch 73/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 377.8063 - mean_absolute_error: 15.5874 - mean_squared_error: 377.8062 - val_loss: 664.2164 - val_mean_absolute_error: 20.5248 - val_mean_squared_error: 664.3141
# Epoch 74/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 378.0764 - mean_absolute_error: 15.5759 - mean_squared_error: 378.0764 - val_loss: 720.5859 - val_mean_absolute_error: 21.4590 - val_mean_squared_error: 720.7036
# Epoch 75/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 377.7017 - mean_absolute_error: 15.5547 - mean_squared_error: 377.7017 - val_loss: 750.5475 - val_mean_absolute_error: 21.8232 - val_mean_squared_error: 750.6429
# Epoch 76/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 372.2528 - mean_absolute_error: 15.4793 - mean_squared_error: 372.2528 - val_loss: 708.9108 - val_mean_absolute_error: 21.1412 - val_mean_squared_error: 709.0454
# Epoch 77/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 371.3156 - mean_absolute_error: 15.4219 - mean_squared_error: 371.3156 - val_loss: 759.6584 - val_mean_absolute_error: 21.9910 - val_mean_squared_error: 759.7836
# Epoch 78/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 369.8572 - mean_absolute_error: 15.3900 - mean_squared_error: 369.8572 - val_loss: 684.5521 - val_mean_absolute_error: 20.8744 - val_mean_squared_error: 684.6915
# Epoch 79/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 368.8151 - mean_absolute_error: 15.3578 - mean_squared_error: 368.8151 - val_loss: 797.6309 - val_mean_absolute_error: 22.5383 - val_mean_squared_error: 797.7330
# Epoch 80/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 368.1739 - mean_absolute_error: 15.3437 - mean_squared_error: 368.1739 - val_loss: 694.1039 - val_mean_absolute_error: 21.0043 - val_mean_squared_error: 694.2701
# Epoch 81/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 367.6763 - mean_absolute_error: 15.3260 - mean_squared_error: 367.6763 - val_loss: 693.4205 - val_mean_absolute_error: 20.9636 - val_mean_squared_error: 693.5707
# Epoch 82/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 365.9135 - mean_absolute_error: 15.2861 - mean_squared_error: 365.9135 - val_loss: 732.3577 - val_mean_absolute_error: 21.5487 - val_mean_squared_error: 732.5430
# Epoch 83/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 360.2980 - mean_absolute_error: 15.1584 - mean_squared_error: 360.2979 - val_loss: 736.4723 - val_mean_absolute_error: 21.7081 - val_mean_squared_error: 736.6447
# Epoch 84/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 362.7526 - mean_absolute_error: 15.1964 - mean_squared_error: 362.7526 - val_loss: 726.2683 - val_mean_absolute_error: 21.5300 - val_mean_squared_error: 726.4420
# Epoch 85/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 359.6738 - mean_absolute_error: 15.1140 - mean_squared_error: 359.6738 - val_loss: 697.2023 - val_mean_absolute_error: 21.0432 - val_mean_squared_error: 697.4033
# Epoch 86/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 360.0097 - mean_absolute_error: 15.1384 - mean_squared_error: 360.0097 - val_loss: 727.2903 - val_mean_absolute_error: 21.6397 - val_mean_squared_error: 727.4774
# Epoch 87/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 357.8721 - mean_absolute_error: 15.0882 - mean_squared_error: 357.8721 - val_loss: 758.2781 - val_mean_absolute_error: 22.0098 - val_mean_squared_error: 758.4900
# Epoch 88/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 356.6576 - mean_absolute_error: 15.0454 - mean_squared_error: 356.6576 - val_loss: 740.2580 - val_mean_absolute_error: 21.7777 - val_mean_squared_error: 740.4588
# Epoch 89/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 354.6006 - mean_absolute_error: 14.9944 - mean_squared_error: 354.6006 - val_loss: 706.0540 - val_mean_absolute_error: 21.1623 - val_mean_squared_error: 706.2749
# Epoch 90/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 352.1656 - mean_absolute_error: 14.9164 - mean_squared_error: 352.1656 - val_loss: 717.9676 - val_mean_absolute_error: 21.4366 - val_mean_squared_error: 718.1760
# Epoch 91/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 352.5122 - mean_absolute_error: 14.9396 - mean_squared_error: 352.5122 - val_loss: 759.1392 - val_mean_absolute_error: 22.0593 - val_mean_squared_error: 759.3723
# Epoch 92/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 350.8271 - mean_absolute_error: 14.9153 - mean_squared_error: 350.8271 - val_loss: 806.5818 - val_mean_absolute_error: 22.7949 - val_mean_squared_error: 806.8169
# Epoch 93/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 351.0905 - mean_absolute_error: 14.9192 - mean_squared_error: 351.0905 - val_loss: 750.8654 - val_mean_absolute_error: 21.9132 - val_mean_squared_error: 751.0860
# Epoch 94/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 348.7055 - mean_absolute_error: 14.8407 - mean_squared_error: 348.7055 - val_loss: 772.5759 - val_mean_absolute_error: 22.2628 - val_mean_squared_error: 772.8238
# Epoch 95/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 346.5007 - mean_absolute_error: 14.8030 - mean_squared_error: 346.5007 - val_loss: 668.2921 - val_mean_absolute_error: 20.6033 - val_mean_squared_error: 668.5154
# Epoch 96/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 347.6746 - mean_absolute_error: 14.7981 - mean_squared_error: 347.6746 - val_loss: 706.5786 - val_mean_absolute_error: 21.2569 - val_mean_squared_error: 706.8161
# Epoch 97/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 344.7082 - mean_absolute_error: 14.7329 - mean_squared_error: 344.7082 - val_loss: 744.6382 - val_mean_absolute_error: 21.8176 - val_mean_squared_error: 744.8876
# Epoch 98/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 342.3388 - mean_absolute_error: 14.6894 - mean_squared_error: 342.3389 - val_loss: 737.4458 - val_mean_absolute_error: 21.7804 - val_mean_squared_error: 737.6893
# Epoch 99/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 340.9358 - mean_absolute_error: 14.6481 - mean_squared_error: 340.9358 - val_loss: 709.4871 - val_mean_absolute_error: 21.3003 - val_mean_squared_error: 709.7326
# Epoch 100/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 341.5578 - mean_absolute_error: 14.6469 - mean_squared_error: 341.5578 - val_loss: 744.3626 - val_mean_absolute_error: 21.8420 - val_mean_squared_error: 744.6145
# Epoch 101/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 337.5728 - mean_absolute_error: 14.5667 - mean_squared_error: 337.5728 - val_loss: 750.7313 - val_mean_absolute_error: 21.8888 - val_mean_squared_error: 750.9951
# Epoch 102/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 336.2472 - mean_absolute_error: 14.5191 - mean_squared_error: 336.2473 - val_loss: 778.0157 - val_mean_absolute_error: 22.3523 - val_mean_squared_error: 778.2867
# Epoch 103/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 337.3581 - mean_absolute_error: 14.5339 - mean_squared_error: 337.3580 - val_loss: 790.9305 - val_mean_absolute_error: 22.5617 - val_mean_squared_error: 791.2061
# Epoch 104/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 335.8008 - mean_absolute_error: 14.4951 - mean_squared_error: 335.8008 - val_loss: 712.8608 - val_mean_absolute_error: 21.3531 - val_mean_squared_error: 713.1142
# Epoch 105/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 334.4299 - mean_absolute_error: 14.4701 - mean_squared_error: 334.4299 - val_loss: 725.8219 - val_mean_absolute_error: 21.4986 - val_mean_squared_error: 726.0812
# Epoch 106/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 331.5272 - mean_absolute_error: 14.3811 - mean_squared_error: 331.5272 - val_loss: 725.4044 - val_mean_absolute_error: 21.5701 - val_mean_squared_error: 725.6572
# Epoch 107/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 330.3682 - mean_absolute_error: 14.3581 - mean_squared_error: 330.3682 - val_loss: 759.1642 - val_mean_absolute_error: 22.1022 - val_mean_squared_error: 759.4343
# Epoch 108/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 328.5240 - mean_absolute_error: 14.3264 - mean_squared_error: 328.5240 - val_loss: 716.4122 - val_mean_absolute_error: 21.4336 - val_mean_squared_error: 716.6703
# Epoch 109/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 328.5055 - mean_absolute_error: 14.3144 - mean_squared_error: 328.5055 - val_loss: 811.4881 - val_mean_absolute_error: 22.8838 - val_mean_squared_error: 811.7688
# Epoch 110/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 325.0295 - mean_absolute_error: 14.2262 - mean_squared_error: 325.0296 - val_loss: 756.2139 - val_mean_absolute_error: 22.0436 - val_mean_squared_error: 756.4807
# Epoch 111/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 327.5906 - mean_absolute_error: 14.2831 - mean_squared_error: 327.5907 - val_loss: 796.6893 - val_mean_absolute_error: 22.6718 - val_mean_squared_error: 796.9810
# Epoch 112/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 327.7466 - mean_absolute_error: 14.2720 - mean_squared_error: 327.7466 - val_loss: 786.9101 - val_mean_absolute_error: 22.4546 - val_mean_squared_error: 787.2050
# Epoch 113/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 326.0646 - mean_absolute_error: 14.2403 - mean_squared_error: 326.0646 - val_loss: 758.8949 - val_mean_absolute_error: 22.1461 - val_mean_squared_error: 759.1759
# Epoch 114/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 322.4464 - mean_absolute_error: 14.1462 - mean_squared_error: 322.4465 - val_loss: 812.7188 - val_mean_absolute_error: 22.8991 - val_mean_squared_error: 813.0303
# Epoch 115/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 322.5062 - mean_absolute_error: 14.1456 - mean_squared_error: 322.5062 - val_loss: 785.6122 - val_mean_absolute_error: 22.4410 - val_mean_squared_error: 785.8997
# Epoch 116/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 321.9839 - mean_absolute_error: 14.1230 - mean_squared_error: 321.9839 - val_loss: 850.2629 - val_mean_absolute_error: 23.4546 - val_mean_squared_error: 850.5828
# Epoch 117/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 321.4606 - mean_absolute_error: 14.1115 - mean_squared_error: 321.4606 - val_loss: 754.8217 - val_mean_absolute_error: 21.9469 - val_mean_squared_error: 755.0969
# Epoch 118/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 316.9442 - mean_absolute_error: 14.0008 - mean_squared_error: 316.9443 - val_loss: 782.2965 - val_mean_absolute_error: 22.4710 - val_mean_squared_error: 782.5950
# Epoch 119/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 317.3421 - mean_absolute_error: 14.0252 - mean_squared_error: 317.3421 - val_loss: 754.9546 - val_mean_absolute_error: 21.9092 - val_mean_squared_error: 755.2393
# Epoch 120/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 317.1862 - mean_absolute_error: 14.0212 - mean_squared_error: 317.1862 - val_loss: 806.2961 - val_mean_absolute_error: 22.6925 - val_mean_squared_error: 806.5929
# Epoch 121/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 314.1585 - mean_absolute_error: 13.9398 - mean_squared_error: 314.1585 - val_loss: 754.4631 - val_mean_absolute_error: 21.9642 - val_mean_squared_error: 754.7303
# Epoch 122/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 314.2442 - mean_absolute_error: 13.9242 - mean_squared_error: 314.2442 - val_loss: 802.7735 - val_mean_absolute_error: 22.6765 - val_mean_squared_error: 803.0798
# Epoch 123/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 310.9228 - mean_absolute_error: 13.8514 - mean_squared_error: 310.9228 - val_loss: 827.7162 - val_mean_absolute_error: 23.2395 - val_mean_squared_error: 828.0269
# Epoch 124/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 310.8082 - mean_absolute_error: 13.8420 - mean_squared_error: 310.8082 - val_loss: 814.7666 - val_mean_absolute_error: 22.9161 - val_mean_squared_error: 815.0738
# Epoch 125/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 311.3936 - mean_absolute_error: 13.8486 - mean_squared_error: 311.3936 - val_loss: 803.2904 - val_mean_absolute_error: 22.7190 - val_mean_squared_error: 803.5920
# Epoch 126/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 309.2414 - mean_absolute_error: 13.8049 - mean_squared_error: 309.2414 - val_loss: 861.1528 - val_mean_absolute_error: 23.5342 - val_mean_squared_error: 861.4760
# Epoch 127/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 309.2713 - mean_absolute_error: 13.7980 - mean_squared_error: 309.2713 - val_loss: 834.1746 - val_mean_absolute_error: 23.1490 - val_mean_squared_error: 834.4868
# Epoch 128/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 306.4691 - mean_absolute_error: 13.7349 - mean_squared_error: 306.4691 - val_loss: 874.7068 - val_mean_absolute_error: 23.7676 - val_mean_squared_error: 875.0350
# Epoch 129/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 309.3083 - mean_absolute_error: 13.8162 - mean_squared_error: 309.3083 - val_loss: 831.4694 - val_mean_absolute_error: 23.0768 - val_mean_squared_error: 831.7914
# Epoch 130/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 305.0561 - mean_absolute_error: 13.7014 - mean_squared_error: 305.0561 - val_loss: 892.4866 - val_mean_absolute_error: 23.9954 - val_mean_squared_error: 892.8268
# Epoch 131/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 304.8144 - mean_absolute_error: 13.6818 - mean_squared_error: 304.8144 - val_loss: 876.4644 - val_mean_absolute_error: 23.6945 - val_mean_squared_error: 876.8002
# Epoch 132/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 302.2657 - mean_absolute_error: 13.6037 - mean_squared_error: 302.2657 - val_loss: 805.0746 - val_mean_absolute_error: 22.7368 - val_mean_squared_error: 805.3726
# Epoch 133/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 302.4057 - mean_absolute_error: 13.6453 - mean_squared_error: 302.4057 - val_loss: 867.4253 - val_mean_absolute_error: 23.6322 - val_mean_squared_error: 867.7555
# Epoch 134/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 302.3560 - mean_absolute_error: 13.6437 - mean_squared_error: 302.3560 - val_loss: 901.8572 - val_mean_absolute_error: 24.1674 - val_mean_squared_error: 902.2072
# Epoch 135/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 300.9004 - mean_absolute_error: 13.6034 - mean_squared_error: 300.9004 - val_loss: 869.8048 - val_mean_absolute_error: 23.5324 - val_mean_squared_error: 870.1418
# Epoch 136/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 298.5057 - mean_absolute_error: 13.5162 - mean_squared_error: 298.5057 - val_loss: 948.9973 - val_mean_absolute_error: 24.9079 - val_mean_squared_error: 949.3716
# Epoch 137/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 299.8159 - mean_absolute_error: 13.5579 - mean_squared_error: 299.8159 - val_loss: 885.2643 - val_mean_absolute_error: 23.8177 - val_mean_squared_error: 885.6052
# Epoch 138/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 296.0501 - mean_absolute_error: 13.4827 - mean_squared_error: 296.0501 - val_loss: 896.0077 - val_mean_absolute_error: 24.0397 - val_mean_squared_error: 896.3470
# Epoch 139/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 297.4881 - mean_absolute_error: 13.4941 - mean_squared_error: 297.4881 - val_loss: 891.3965 - val_mean_absolute_error: 23.9831 - val_mean_squared_error: 891.7551
# Epoch 140/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 295.5715 - mean_absolute_error: 13.4566 - mean_squared_error: 295.5715 - val_loss: 882.6187 - val_mean_absolute_error: 23.8100 - val_mean_squared_error: 882.9608
# Epoch 141/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 295.5869 - mean_absolute_error: 13.4552 - mean_squared_error: 295.5869 - val_loss: 860.9467 - val_mean_absolute_error: 23.3745 - val_mean_squared_error: 861.2836
# Epoch 142/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 294.6931 - mean_absolute_error: 13.4418 - mean_squared_error: 294.6931 - val_loss: 905.8934 - val_mean_absolute_error: 24.1135 - val_mean_squared_error: 906.2532
# Epoch 143/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 294.9143 - mean_absolute_error: 13.4076 - mean_squared_error: 294.9143 - val_loss: 879.1472 - val_mean_absolute_error: 23.6983 - val_mean_squared_error: 879.4973
# Epoch 144/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 293.7001 - mean_absolute_error: 13.4022 - mean_squared_error: 293.7001 - val_loss: 950.9681 - val_mean_absolute_error: 24.7422 - val_mean_squared_error: 951.3466
# Epoch 145/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 294.1012 - mean_absolute_error: 13.4243 - mean_squared_error: 294.1012 - val_loss: 921.5139 - val_mean_absolute_error: 24.3648 - val_mean_squared_error: 921.8719
# Epoch 146/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 292.8436 - mean_absolute_error: 13.3878 - mean_squared_error: 292.8436 - val_loss: 1025.9320 - val_mean_absolute_error: 25.8799 - val_mean_squared_error: 1026.3268
# Epoch 147/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 290.8747 - mean_absolute_error: 13.3398 - mean_squared_error: 290.8747 - val_loss: 888.1152 - val_mean_absolute_error: 23.8314 - val_mean_squared_error: 888.4710
# Epoch 148/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 290.9359 - mean_absolute_error: 13.3358 - mean_squared_error: 290.9359 - val_loss: 911.4292 - val_mean_absolute_error: 24.1284 - val_mean_squared_error: 911.7937
# Epoch 149/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 291.4808 - mean_absolute_error: 13.3579 - mean_squared_error: 291.4808 - val_loss: 1024.0339 - val_mean_absolute_error: 25.7692 - val_mean_squared_error: 1024.4393
# Epoch 150/150
# 1898/1898 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 289.7864 - mean_absolute_error: 13.3167 - mean_squared_error: 289.7864 - val_loss: 970.5065 - val_mean_absolute_error: 25.0867 - val_mean_squared_error: 970.8911

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([70,700])
  plt.xlabel('Epoch')
  plt.ylabel('Error [MPG]')
  plt.legend()
  plt.grid(True)
plot_loss(history)

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, GRU, SimpleRNN, Dropout
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split



est = [(74,7), (148,4), (67,1)]
# Cargar datos de concentración
df_leg = df_dict['(74,7)']
df_torr = df_dict['(148,4)']
df_guad = df_dict['(67,1)']

# Crear las secuencias de datos

"""
def create_seq(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:i+seq_length]
        y = data[i+seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)
"""
def create_seq(data, data_y, seq_length):
    
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:i+seq_length]
        y = data_y[i+seq_length]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

def prepara_datos(df, num_cont, window_size, ):
    #Normalizamos los datos de entrenamiento 
    scaler = StandardScaler()
    df_data = df[[f'{num_cont}']].copy()
    df_normal = pd.DataFrame(scaler.fit_transform(df_data), columns=df_data.columns)
   

    # Seleccionar la columna de concentración
    data = df_normal.values
    data_y = df[[f'{num_cont}']].copy().values
    
    """
    # Seleccionar la columna de concentración
    data = df[[f'{num_cont}']].values
    """
 

    #Crear secuencias de datos
    X,Y = create_seq(data, data_y, window_size)
    

    # Dividir los datos en conjuntos de entrenamiento y prueba
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    Y_train, Y_test = Y[:train_size], Y[train_size:]

    return X_train, X_test, Y_train, Y_test

def DNN(window, X_train, Y_train, num_epochs, b_size, val_split):
    model=Sequential()
    #model.add(Dense(units=100, input_dim=window, activation='relu'))

    model.add(Dense(units=100, input_dim=window, activation='tanh'))
    #model.add(Dense(8, activation='relu'))
    #model.add(Dense(units=50, activation='relu'))
    #model.add(Dense(25, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mse', 'mae'])

    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    model.fit(X_train, Y_train, epochs=num_epochs, batch_size=b_size, validation_split=val_split, callbacks=[early_stopping])
    return model

def RNN(window_size, X_train, Y_train, num_epochs, b_size, val_split):
    
    # Definir el modelo
    model = Sequential()
    model.add(SimpleRNN(100, activation="tanh", input_shape=(window_size, 1)))
    model.add(Dense(1))

    # Compilar el modelo
    model.compile(optimizer='adam', loss='mean_squared_error', metrics = ['mse', 'mae'])
    
    #Regularización 
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Entrenar el modelo
    model.fit(X_train, Y_train, epochs=num_epochs, batch_size=b_size, validation_split=val_split, callbacks=[early_stopping])

    return model 

def RNN_LSTM(window_size, X_train, Y_train, num_epochs, b_size, val_split):
    
    # Definir el modelo
    model = Sequential()
    model.add(LSTM(100, activation="tanh",input_shape=(window_size, 1)))
    #model.add(Dense(1))
    
    """
    # Segunda capa LSTM
    model.add(LSTM(100, activation="tanh", return_sequences=True))
    model.add(Dropout(0.2))
    
    # Tercera capa LSTM
    model.add(LSTM(50, activation="tanh"))
    model.add(Dropout(0.2))
    """
    model.add(Dense(1))
     
    # Compilar el modelo
    model.compile(optimizer='adam', loss='mean_squared_error', metrics = ['mse', 'mae'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)


    # Entrenar el modelo
    model.fit(X_train, Y_train, epochs=num_epochs, batch_size=b_size, validation_split=val_split, callbacks=[early_stopping])

    return model 

def RNN_GRU(window_size, X_train, Y_train, num_epochs, b_size, val_split):
    
    # Definir el modelo
    model = Sequential()
    model.add(GRU(150, activation="tanh", input_shape=(window_size, 1)))
    model.add(Dense(1))

    # Compilar el modelo
    model.compile(optimizer='adam', loss='mean_squared_error', metrics = ['mse', 'mae'])
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Entrenar el modelo
    model.fit(X_train, Y_train, epochs=num_epochs, batch_size=b_size, validation_split=val_split, callbacks=[early_stopping])

    return model 



def create_model_test(df, num_cont, window_size, num_epochs, b_size, val_split, mod):
    X_train, X_test, Y_train, Y_test = prepara_datos(df, num_cont, window_size)
    model = mod(window_size, X_train, Y_train, num_epochs, b_size, val_split)
    return model, X_test, Y_test

# %%
#Modelos para Guadalix de la Sierra 
model_guad_8, X_test_g_8, Y_test_g_8 = create_model_test(df_guad, 8, 3, 150, 32, 0.2, DNN)
model_guad_10, X_test_g_10, Y_test_g_10  = create_model_test(df_guad, 10, 3, 150, 32, 0.2, DNN)
model_guad_14, X_test_g_14, Y_test_g_14  = create_model_test(df_guad, 14, 3, 150, 32, 0.2, DNN)
# Out:
# c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - loss: 64.8346 - mae: 5.0204 - mse: 64.8346 - val_loss: 22.7644 - val_mae: 2.9872 - val_mse: 22.6228
# Epoch 2/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 25.0413 - mae: 2.9527 - mse: 25.0413 - val_loss: 22.3121 - val_mae: 2.7284 - val_mse: 22.2071
# Epoch 3/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 23.8610 - mae: 2.8629 - mse: 23.8610 - val_loss: 22.1814 - val_mae: 2.7326 - val_mse: 22.1116
# Epoch 4/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 24.0327 - mae: 2.8801 - mse: 24.0327 - val_loss: 22.0855 - val_mae: 2.7033 - val_mse: 22.0159
# Epoch 5/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 23.5892 - mae: 2.8409 - mse: 23.5892 - val_loss: 21.9143 - val_mae: 2.6843 - val_mse: 21.8479
# Epoch 6/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 23.9594 - mae: 2.8579 - mse: 23.9594 - val_loss: 21.8881 - val_mae: 2.6693 - val_mse: 21.8304
# Epoch 7/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 23.4922 - mae: 2.8320 - mse: 23.4922 - val_loss: 21.7583 - val_mae: 2.6776 - val_mse: 21.6829
# Epoch 8/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 23.8919 - mae: 2.8494 - mse: 23.8919 - val_loss: 21.8003 - val_mae: 2.7386 - val_mse: 21.7509
# Epoch 9/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 24.1808 - mae: 2.8777 - mse: 24.1808 - val_loss: 22.1226 - val_mae: 2.6811 - val_mse: 22.0651
# Epoch 10/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 23.3578 - mae: 2.8221 - mse: 23.3578 - val_loss: 21.7299 - val_mae: 2.6923 - val_mse: 21.6855
# Epoch 11/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 23.9266 - mae: 2.8442 - mse: 23.9266 - val_loss: 21.6676 - val_mae: 2.7423 - val_mse: 21.5970
# Epoch 12/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 23.0459 - mae: 2.8345 - mse: 23.0459 - val_loss: 21.8326 - val_mae: 2.6884 - val_mse: 21.7759
# Epoch 13/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 23.9391 - mae: 2.8351 - mse: 23.9390 - val_loss: 21.5767 - val_mae: 2.7461 - val_mse: 21.5229
# Epoch 14/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 24.4980 - mae: 2.8631 - mse: 24.4980 - val_loss: 21.5282 - val_mae: 2.7200 - val_mse: 21.4783
# Epoch 15/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 23.6589 - mae: 2.8343 - mse: 23.6589 - val_loss: 21.3600 - val_mae: 2.7164 - val_mse: 21.2899
# Epoch 16/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 22.8919 - mae: 2.7927 - mse: 22.8919 - val_loss: 21.5830 - val_mae: 2.6402 - val_mse: 21.5044
# Epoch 17/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 23.8147 - mae: 2.8360 - mse: 23.8147 - val_loss: 21.2756 - val_mae: 2.7229 - val_mse: 21.2116
# Epoch 18/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 23.3091 - mae: 2.8217 - mse: 23.3091 - val_loss: 21.9846 - val_mae: 2.7392 - val_mse: 21.9600
# Epoch 19/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 23.9946 - mae: 2.8525 - mse: 23.9946 - val_loss: 21.1744 - val_mae: 2.6825 - val_mse: 21.1146
# Epoch 20/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 23.5528 - mae: 2.8386 - mse: 23.5528 - val_loss: 21.3900 - val_mae: 2.6981 - val_mse: 21.3380
# Epoch 21/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 22.6821 - mae: 2.7668 - mse: 22.6821 - val_loss: 22.2206 - val_mae: 2.6856 - val_mse: 22.1853
# Epoch 22/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 23.9785 - mae: 2.8297 - mse: 23.9785 - val_loss: 21.3164 - val_mae: 2.7035 - val_mse: 21.2642
# Epoch 23/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 24.3953 - mae: 2.8834 - mse: 24.3953 - val_loss: 21.4641 - val_mae: 2.7040 - val_mse: 21.4090
# Epoch 24/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 22.6924 - mae: 2.7866 - mse: 22.6924 - val_loss: 21.2777 - val_mae: 2.7340 - val_mse: 21.2051
# Epoch 25/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 22.5754 - mae: 2.7822 - mse: 22.5754 - val_loss: 21.7395 - val_mae: 2.7837 - val_mse: 21.6912
# Epoch 26/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 22.9048 - mae: 2.8189 - mse: 22.9048 - val_loss: 21.3296 - val_mae: 2.6424 - val_mse: 21.2612
# Epoch 27/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 23.2231 - mae: 2.8029 - mse: 23.2231 - val_loss: 21.4992 - val_mae: 2.7477 - val_mse: 21.4454
# Epoch 28/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 22.8801 - mae: 2.7934 - mse: 22.8801 - val_loss: 21.3899 - val_mae: 2.8005 - val_mse: 21.3214
# Epoch 29/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 23.2198 - mae: 2.8123 - mse: 23.2198 - val_loss: 21.2550 - val_mae: 2.6813 - val_mse: 21.1924
# Epoch 1/150
# c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - loss: 132.4961 - mae: 6.6615 - mse: 132.4962 - val_loss: 504.7434 - val_mae: 5.0156 - val_mse: 506.2483
# Epoch 2/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 41.2890 - mae: 3.7506 - mse: 41.2891 - val_loss: 444.0201 - val_mae: 4.7169 - val_mse: 445.3418
# Epoch 3/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 35.2848 - mae: 3.6220 - mse: 35.2848 - val_loss: 403.6899 - val_mae: 4.8420 - val_mse: 404.8875
# Epoch 4/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 34.3315 - mae: 3.6112 - mse: 34.3315 - val_loss: 370.3494 - val_mae: 4.5921 - val_mse: 371.4493
# Epoch 5/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 30.1812 - mae: 3.5891 - mse: 30.1812 - val_loss: 340.2775 - val_mae: 4.5506 - val_mse: 341.2874
# Epoch 6/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 29.1164 - mae: 3.5616 - mse: 29.1164 - val_loss: 315.9411 - val_mae: 4.4771 - val_mse: 316.8786
# Epoch 7/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 28.2135 - mae: 3.5302 - mse: 28.2135 - val_loss: 297.9797 - val_mae: 4.5745 - val_mse: 298.8625
# Epoch 8/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 28.1711 - mae: 3.5540 - mse: 28.1711 - val_loss: 281.5166 - val_mae: 4.4990 - val_mse: 282.3503
# Epoch 9/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 27.6863 - mae: 3.5561 - mse: 27.6863 - val_loss: 268.1599 - val_mae: 4.3776 - val_mse: 268.9538
# Epoch 10/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 27.2986 - mae: 3.5186 - mse: 27.2986 - val_loss: 256.7154 - val_mae: 4.4948 - val_mse: 257.4725
# Epoch 11/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 27.0541 - mae: 3.5431 - mse: 27.0541 - val_loss: 247.9568 - val_mae: 4.3815 - val_mse: 248.6892
# Epoch 12/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 26.4133 - mae: 3.5221 - mse: 26.4133 - val_loss: 241.7083 - val_mae: 4.4618 - val_mse: 242.4208
# Epoch 13/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 27.1815 - mae: 3.5565 - mse: 27.1815 - val_loss: 229.9478 - val_mae: 4.3748 - val_mse: 230.6266
# Epoch 14/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 26.1580 - mae: 3.4899 - mse: 26.1580 - val_loss: 225.1563 - val_mae: 4.2885 - val_mse: 225.8207
# Epoch 15/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 26.5330 - mae: 3.5177 - mse: 26.5330 - val_loss: 219.9958 - val_mae: 4.3093 - val_mse: 220.6441
# Epoch 16/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.5345 - mae: 3.5115 - mse: 25.5345 - val_loss: 214.3768 - val_mae: 4.3111 - val_mse: 215.0084
# Epoch 17/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.3096 - mae: 3.5220 - mse: 26.3096 - val_loss: 211.8289 - val_mae: 4.2728 - val_mse: 212.4537
# Epoch 18/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 26.1097 - mae: 3.4944 - mse: 26.1097 - val_loss: 207.9545 - val_mae: 4.2865 - val_mse: 208.5679
# Epoch 19/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 26.5093 - mae: 3.5233 - mse: 26.5093 - val_loss: 205.1783 - val_mae: 4.3493 - val_mse: 205.7811
# Epoch 20/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 25.7784 - mae: 3.5022 - mse: 25.7784 - val_loss: 204.8134 - val_mae: 4.2711 - val_mse: 205.4179
# Epoch 21/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 25.9228 - mae: 3.5092 - mse: 25.9228 - val_loss: 200.9991 - val_mae: 4.3152 - val_mse: 201.5907
# Epoch 22/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 26.4390 - mae: 3.5448 - mse: 26.4390 - val_loss: 200.5737 - val_mae: 4.3502 - val_mse: 201.1638
# Epoch 23/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 27.4100 - mae: 3.5186 - mse: 27.4100 - val_loss: 202.3345 - val_mae: 4.2544 - val_mse: 202.9317
# Epoch 24/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 27.0655 - mae: 3.5341 - mse: 27.0655 - val_loss: 195.4802 - val_mae: 4.2259 - val_mse: 196.0564
# Epoch 25/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.0556 - mae: 3.5149 - mse: 26.0556 - val_loss: 194.4764 - val_mae: 4.2264 - val_mse: 195.0495
# Epoch 26/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.2158 - mae: 3.4697 - mse: 25.2158 - val_loss: 195.4976 - val_mae: 4.3183 - val_mse: 196.0728
# Epoch 27/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 27.8838 - mae: 3.5341 - mse: 27.8838 - val_loss: 195.4275 - val_mae: 4.2162 - val_mse: 196.0032
# Epoch 28/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.6911 - mae: 3.4846 - mse: 25.6911 - val_loss: 194.5991 - val_mae: 4.2319 - val_mse: 195.1726
# Epoch 29/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.2627 - mae: 3.5153 - mse: 26.2627 - val_loss: 193.8464 - val_mae: 4.3244 - val_mse: 194.4171
# Epoch 30/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 26.0222 - mae: 3.5193 - mse: 26.0222 - val_loss: 193.5319 - val_mae: 4.2937 - val_mse: 194.1003
# Epoch 31/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 25.9498 - mae: 3.5023 - mse: 25.9498 - val_loss: 191.7766 - val_mae: 4.2506 - val_mse: 192.3426
# Epoch 32/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.8630 - mae: 3.5056 - mse: 25.8629 - val_loss: 191.7595 - val_mae: 4.2832 - val_mse: 192.3214
# Epoch 33/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 26.5691 - mae: 3.5269 - mse: 26.5691 - val_loss: 191.4418 - val_mae: 4.2809 - val_mse: 192.0053
# Epoch 34/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.4926 - mae: 3.5039 - mse: 26.4926 - val_loss: 189.3932 - val_mae: 4.2635 - val_mse: 189.9485
# Epoch 35/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.4707 - mae: 3.5177 - mse: 26.4707 - val_loss: 189.4351 - val_mae: 4.2443 - val_mse: 189.9920
# Epoch 36/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.8356 - mae: 3.5252 - mse: 25.8356 - val_loss: 188.3350 - val_mae: 4.2143 - val_mse: 188.8887
# Epoch 37/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.4846 - mae: 3.4994 - mse: 25.4846 - val_loss: 187.9728 - val_mae: 4.2199 - val_mse: 188.5248
# Epoch 38/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 26.1894 - mae: 3.5015 - mse: 26.1894 - val_loss: 186.6133 - val_mae: 4.2573 - val_mse: 187.1613
# Epoch 39/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.2647 - mae: 3.4719 - mse: 25.2647 - val_loss: 186.5333 - val_mae: 4.2321 - val_mse: 187.0817
# Epoch 40/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.9737 - mae: 3.4951 - mse: 25.9737 - val_loss: 184.7634 - val_mae: 4.2741 - val_mse: 185.3058
# Epoch 41/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 25.4692 - mae: 3.5067 - mse: 25.4692 - val_loss: 187.6487 - val_mae: 4.2554 - val_mse: 188.2017
# Epoch 42/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.4193 - mae: 3.4827 - mse: 25.4193 - val_loss: 185.8143 - val_mae: 4.3819 - val_mse: 186.3593
# Epoch 43/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.2455 - mae: 3.5332 - mse: 26.2455 - val_loss: 187.0871 - val_mae: 4.1922 - val_mse: 187.6373
# Epoch 44/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.8137 - mae: 3.5261 - mse: 26.8137 - val_loss: 187.0421 - val_mae: 4.2939 - val_mse: 187.5915
# Epoch 45/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 25.9076 - mae: 3.4891 - mse: 25.9076 - val_loss: 185.8092 - val_mae: 4.2277 - val_mse: 186.3559
# Epoch 46/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.7287 - mae: 3.5053 - mse: 25.7287 - val_loss: 184.3580 - val_mae: 4.2430 - val_mse: 184.8995
# Epoch 47/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.2285 - mae: 3.4993 - mse: 25.2284 - val_loss: 187.5666 - val_mae: 4.2738 - val_mse: 188.1175
# Epoch 48/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.1346 - mae: 3.5056 - mse: 26.1346 - val_loss: 183.7720 - val_mae: 4.2805 - val_mse: 184.3122
# Epoch 49/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.1660 - mae: 3.5109 - mse: 26.1660 - val_loss: 185.2182 - val_mae: 4.2695 - val_mse: 185.7623
# Epoch 50/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.3951 - mae: 3.5176 - mse: 26.3951 - val_loss: 183.4002 - val_mae: 4.2021 - val_mse: 183.9398
# Epoch 51/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.6434 - mae: 3.5164 - mse: 26.6434 - val_loss: 185.0871 - val_mae: 4.2301 - val_mse: 185.6307
# Epoch 52/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 24.8595 - mae: 3.4620 - mse: 24.8595 - val_loss: 183.7872 - val_mae: 4.2398 - val_mse: 184.3262
# Epoch 53/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.5684 - mae: 3.5079 - mse: 25.5684 - val_loss: 181.6848 - val_mae: 4.2345 - val_mse: 182.2186
# Epoch 54/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 25.9589 - mae: 3.5071 - mse: 25.9589 - val_loss: 181.6477 - val_mae: 4.1868 - val_mse: 182.1817
# Epoch 55/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 27.2225 - mae: 3.5519 - mse: 27.2225 - val_loss: 178.2137 - val_mae: 4.3275 - val_mse: 178.7355
# Epoch 56/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.5844 - mae: 3.5082 - mse: 26.5844 - val_loss: 176.7801 - val_mae: 4.2445 - val_mse: 177.2984
# Epoch 57/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 24.5240 - mae: 3.4462 - mse: 24.5240 - val_loss: 178.3864 - val_mae: 4.2382 - val_mse: 178.9101
# Epoch 58/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.9053 - mae: 3.4971 - mse: 25.9052 - val_loss: 181.6912 - val_mae: 4.2600 - val_mse: 182.2235
# Epoch 59/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.1229 - mae: 3.4924 - mse: 25.1229 - val_loss: 178.4364 - val_mae: 4.1979 - val_mse: 178.9599
# Epoch 60/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.4957 - mae: 3.4826 - mse: 25.4957 - val_loss: 176.4102 - val_mae: 4.1815 - val_mse: 176.9290
# Epoch 61/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.9353 - mae: 3.5106 - mse: 25.9353 - val_loss: 176.5680 - val_mae: 4.2530 - val_mse: 177.0861
# Epoch 62/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.5735 - mae: 3.4976 - mse: 25.5735 - val_loss: 175.1007 - val_mae: 4.2345 - val_mse: 175.6154
# Epoch 63/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.8761 - mae: 3.4959 - mse: 25.8761 - val_loss: 176.5715 - val_mae: 4.1979 - val_mse: 177.0901
# Epoch 64/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 24.9766 - mae: 3.4619 - mse: 24.9766 - val_loss: 177.4769 - val_mae: 4.2850 - val_mse: 177.9969
# Epoch 65/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.1999 - mae: 3.5097 - mse: 25.1999 - val_loss: 178.6909 - val_mae: 4.2850 - val_mse: 179.2149
# Epoch 66/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 25.2779 - mae: 3.4973 - mse: 25.2779 - val_loss: 182.6946 - val_mae: 4.2516 - val_mse: 183.2309
# Epoch 67/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.9206 - mae: 3.4892 - mse: 25.9206 - val_loss: 176.5895 - val_mae: 4.1980 - val_mse: 177.1073
# Epoch 68/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.4108 - mae: 3.5080 - mse: 26.4108 - val_loss: 180.7341 - val_mae: 4.2320 - val_mse: 181.2650
# Epoch 69/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.3243 - mae: 3.4839 - mse: 25.3243 - val_loss: 175.3213 - val_mae: 4.2529 - val_mse: 175.8350
# Epoch 70/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.3984 - mae: 3.5025 - mse: 26.3984 - val_loss: 176.6781 - val_mae: 4.1856 - val_mse: 177.1962
# Epoch 71/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 25.6645 - mae: 3.4833 - mse: 25.6645 - val_loss: 175.2969 - val_mae: 4.2038 - val_mse: 175.8116
# Epoch 72/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 26.0578 - mae: 3.5041 - mse: 26.0578 - val_loss: 177.5215 - val_mae: 4.2617 - val_mse: 178.0414
# Epoch 1/150
# c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1816.5183 - mae: 32.0492 - mse: 1816.5188 - val_loss: 211.4393 - val_mae: 10.1181 - val_mse: 211.7163
# Epoch 2/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 172.8624 - mae: 9.1735 - mse: 172.8625 - val_loss: 117.3710 - val_mae: 7.2605 - val_mse: 117.4378
# Epoch 3/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 108.9448 - mae: 7.1049 - mse: 108.9448 - val_loss: 100.5379 - val_mae: 6.6446 - val_mse: 100.5508
# Epoch 4/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 100.0986 - mae: 6.8488 - mse: 100.0986 - val_loss: 98.5877 - val_mae: 6.7407 - val_mse: 98.5791
# Epoch 5/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 96.4692 - mae: 6.6698 - mse: 96.4692 - val_loss: 95.4295 - val_mae: 6.6008 - val_mse: 95.4137
# Epoch 6/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 95.5380 - mae: 6.6407 - mse: 95.5380 - val_loss: 98.3955 - val_mae: 6.8691 - val_mse: 98.4027
# Epoch 7/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 93.8891 - mae: 6.6286 - mse: 93.8891 - val_loss: 96.3403 - val_mae: 6.7520 - val_mse: 96.2998
# Epoch 8/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 95.1699 - mae: 6.5698 - mse: 95.1699 - val_loss: 92.7458 - val_mae: 6.4719 - val_mse: 92.6770
# Epoch 9/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 94.2292 - mae: 6.5453 - mse: 94.2293 - val_loss: 92.5209 - val_mae: 6.4434 - val_mse: 92.4489
# Epoch 10/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 92.6789 - mae: 6.5202 - mse: 92.6789 - val_loss: 91.8814 - val_mae: 6.4367 - val_mse: 91.8301
# Epoch 11/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 89.4612 - mae: 6.4508 - mse: 89.4612 - val_loss: 93.4538 - val_mae: 6.5106 - val_mse: 93.4238
# Epoch 12/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 93.8210 - mae: 6.4928 - mse: 93.8210 - val_loss: 90.9014 - val_mae: 6.2819 - val_mse: 90.8746
# Epoch 13/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 94.7751 - mae: 6.5385 - mse: 94.7751 - val_loss: 92.5054 - val_mae: 6.5102 - val_mse: 92.4940
# Epoch 14/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 90.9211 - mae: 6.4548 - mse: 90.9211 - val_loss: 90.9208 - val_mae: 6.3092 - val_mse: 90.8733
# Epoch 15/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 88.6385 - mae: 6.3912 - mse: 88.6385 - val_loss: 90.7621 - val_mae: 6.3152 - val_mse: 90.7226
# Epoch 16/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 91.6497 - mae: 6.4259 - mse: 91.6497 - val_loss: 91.0756 - val_mae: 6.3824 - val_mse: 91.0272
# Epoch 17/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 89.1057 - mae: 6.4036 - mse: 89.1057 - val_loss: 90.7644 - val_mae: 6.3937 - val_mse: 90.7781
# Epoch 18/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 91.2086 - mae: 6.4650 - mse: 91.2086 - val_loss: 90.9615 - val_mae: 6.4091 - val_mse: 90.9063
# Epoch 19/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 89.0691 - mae: 6.4161 - mse: 89.0691 - val_loss: 90.3019 - val_mae: 6.2969 - val_mse: 90.3091
# Epoch 20/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 89.5186 - mae: 6.3951 - mse: 89.5186 - val_loss: 91.4378 - val_mae: 6.5289 - val_mse: 91.4509
# Epoch 21/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 89.7900 - mae: 6.4335 - mse: 89.7901 - val_loss: 90.9842 - val_mae: 6.2545 - val_mse: 91.0013
# Epoch 22/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 90.6023 - mae: 6.4189 - mse: 90.6023 - val_loss: 89.8789 - val_mae: 6.2533 - val_mse: 89.8576
# Epoch 23/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 89.3537 - mae: 6.3738 - mse: 89.3538 - val_loss: 90.4000 - val_mae: 6.4940 - val_mse: 90.4210
# Epoch 24/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 88.2607 - mae: 6.3730 - mse: 88.2607 - val_loss: 89.9519 - val_mae: 6.3517 - val_mse: 89.8946
# Epoch 25/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 90.7981 - mae: 6.4331 - mse: 90.7981 - val_loss: 89.4772 - val_mae: 6.3001 - val_mse: 89.4403
# Epoch 26/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 86.4745 - mae: 6.2991 - mse: 86.4745 - val_loss: 89.3883 - val_mae: 6.2350 - val_mse: 89.4218
# Epoch 27/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 93.3364 - mae: 6.4864 - mse: 93.3365 - val_loss: 89.2768 - val_mae: 6.3592 - val_mse: 89.2546
# Epoch 28/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 90.0231 - mae: 6.3863 - mse: 90.0232 - val_loss: 89.6689 - val_mae: 6.4013 - val_mse: 89.6396
# Epoch 29/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 90.2070 - mae: 6.3639 - mse: 90.2070 - val_loss: 90.7092 - val_mae: 6.3933 - val_mse: 90.7169
# Epoch 30/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 88.8621 - mae: 6.3360 - mse: 88.8621 - val_loss: 88.9163 - val_mae: 6.2220 - val_mse: 88.8651
# Epoch 31/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.9632 - mae: 6.3270 - mse: 87.9632 - val_loss: 90.6068 - val_mae: 6.2622 - val_mse: 90.5900
# Epoch 32/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 86.7250 - mae: 6.2789 - mse: 86.7250 - val_loss: 89.8923 - val_mae: 6.4419 - val_mse: 89.8074
# Epoch 33/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 88.9493 - mae: 6.3705 - mse: 88.9494 - val_loss: 90.1999 - val_mae: 6.4369 - val_mse: 90.1758
# Epoch 34/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.2268 - mae: 6.2989 - mse: 87.2266 - val_loss: 89.2330 - val_mae: 6.2827 - val_mse: 89.1995
# Epoch 35/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 88.1646 - mae: 6.3343 - mse: 88.1646 - val_loss: 89.6450 - val_mae: 6.3892 - val_mse: 89.6410
# Epoch 36/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 90.7943 - mae: 6.4042 - mse: 90.7943 - val_loss: 89.5578 - val_mae: 6.2937 - val_mse: 89.5124
# Epoch 37/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.1960 - mae: 6.2867 - mse: 87.1960 - val_loss: 90.2333 - val_mae: 6.4347 - val_mse: 90.1692
# Epoch 38/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.8832 - mae: 6.3390 - mse: 87.8832 - val_loss: 89.8240 - val_mae: 6.2039 - val_mse: 89.7862
# Epoch 39/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.1900 - mae: 6.3110 - mse: 87.1900 - val_loss: 88.8083 - val_mae: 6.3111 - val_mse: 88.7329
# Epoch 40/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.5734 - mae: 6.3136 - mse: 87.5733 - val_loss: 89.3823 - val_mae: 6.3413 - val_mse: 89.3985
# Epoch 41/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 89.9678 - mae: 6.3833 - mse: 89.9678 - val_loss: 88.7470 - val_mae: 6.3623 - val_mse: 88.7034
# Epoch 42/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 88.0389 - mae: 6.3225 - mse: 88.0389 - val_loss: 89.0607 - val_mae: 6.3203 - val_mse: 88.9939
# Epoch 43/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 86.1300 - mae: 6.2573 - mse: 86.1300 - val_loss: 89.7153 - val_mae: 6.3364 - val_mse: 89.6828
# Epoch 44/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 88.2319 - mae: 6.3216 - mse: 88.2318 - val_loss: 89.0240 - val_mae: 6.2600 - val_mse: 88.9740
# Epoch 45/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 88.7781 - mae: 6.3510 - mse: 88.7781 - val_loss: 88.9966 - val_mae: 6.3361 - val_mse: 88.9830
# Epoch 46/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 91.3324 - mae: 6.4347 - mse: 91.3324 - val_loss: 88.7845 - val_mae: 6.1882 - val_mse: 88.7733
# Epoch 47/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.9551 - mae: 6.3057 - mse: 87.9551 - val_loss: 90.1726 - val_mae: 6.3744 - val_mse: 90.0940
# Epoch 48/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.0429 - mae: 6.2835 - mse: 87.0429 - val_loss: 89.6743 - val_mae: 6.4013 - val_mse: 89.5758
# Epoch 49/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.2616 - mae: 6.2631 - mse: 87.2615 - val_loss: 88.9887 - val_mae: 6.3076 - val_mse: 88.9045
# Epoch 50/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.1088 - mae: 6.2766 - mse: 87.1088 - val_loss: 88.7442 - val_mae: 6.2396 - val_mse: 88.7308
# Epoch 51/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 84.3234 - mae: 6.2242 - mse: 84.3234 - val_loss: 88.4575 - val_mae: 6.2367 - val_mse: 88.4372
# Epoch 52/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.1498 - mae: 6.3086 - mse: 87.1497 - val_loss: 89.3693 - val_mae: 6.2648 - val_mse: 89.3074
# Epoch 53/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 87.3095 - mae: 6.3157 - mse: 87.3096 - val_loss: 89.3261 - val_mae: 6.2684 - val_mse: 89.2449
# Epoch 54/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 86.9068 - mae: 6.2782 - mse: 86.9068 - val_loss: 90.7633 - val_mae: 6.3173 - val_mse: 90.7304
# Epoch 55/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 84.5394 - mae: 6.2173 - mse: 84.5394 - val_loss: 88.4227 - val_mae: 6.2301 - val_mse: 88.3567
# Epoch 56/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 86.0194 - mae: 6.2601 - mse: 86.0194 - val_loss: 88.8076 - val_mae: 6.2862 - val_mse: 88.7314
# Epoch 57/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.8247 - mae: 6.3055 - mse: 87.8247 - val_loss: 89.3644 - val_mae: 6.2411 - val_mse: 89.2965
# Epoch 58/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 85.5962 - mae: 6.2364 - mse: 85.5962 - val_loss: 89.4226 - val_mae: 6.3789 - val_mse: 89.3285
# Epoch 59/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - loss: 87.3679 - mae: 6.2895 - mse: 87.3679 - val_loss: 89.2585 - val_mae: 6.3506 - val_mse: 89.2371
# Epoch 60/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 88.1576 - mae: 6.3212 - mse: 88.1575 - val_loss: 88.7875 - val_mae: 6.2428 - val_mse: 88.7638
# Epoch 61/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.3190 - mae: 6.3047 - mse: 87.3190 - val_loss: 88.9889 - val_mae: 6.3908 - val_mse: 88.9330
# Epoch 62/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 86.6173 - mae: 6.3045 - mse: 86.6174 - val_loss: 89.9702 - val_mae: 6.4441 - val_mse: 89.9258
# Epoch 63/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 88.0661 - mae: 6.3210 - mse: 88.0660 - val_loss: 88.4410 - val_mae: 6.2446 - val_mse: 88.3711
# Epoch 64/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 87.3605 - mae: 6.2892 - mse: 87.3605 - val_loss: 89.0084 - val_mae: 6.3037 - val_mse: 88.9468
# Epoch 65/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 86.1310 - mae: 6.2685 - mse: 86.1310 - val_loss: 89.1002 - val_mae: 6.3393 - val_mse: 89.0556

# %%
# Evaluar el modelo de Guadalix de la Sierra 
loss_guad_8 = model_guad_8.evaluate(X_test_g_8, Y_test_g_8)
loss_guad_10 = model_guad_10.evaluate(X_test_g_10, Y_test_g_10)
loss_guad_14 = model_guad_14.evaluate(X_test_g_14, Y_test_g_14)

print(f"Test Loss 8: {loss_guad_8}")
print(f"Test Loss 10: {loss_guad_10}")
print(f"Test Loss 14: {loss_guad_14}")
# Out:
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 17.8793 - mae: 2.4693 - mse: 17.8794
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 32.9915 - mae: 3.7936 - mse: 32.9918
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 81.1738 - mae: 6.0814 - mse: 81.1738
# Test Loss 8: [16.013696670532227, 2.368195056915283, 16.02600860595703]
# Test Loss 10: [29.646093368530273, 3.415783643722534, 29.687501907348633]
# Test Loss 14: [80.62100219726562, 6.018620491027832, 80.62677764892578]

# %% [markdown]
# DNN(3) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 17.5431 - mae: 2.4490 - mse: 17.5432
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 33.2532 - mae: 3.7156 - mse: 33.2534
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 83.7098 - mae: 6.2006 - mse: 83.7100
# Test Loss 8: [15.848474502563477, 2.365659236907959, 15.858933448791504]
# Test Loss 10: [30.038536071777344, 3.366487979888916, 30.07952880859375]
# Test Loss 14: [83.32794952392578, 6.191246509552002, 83.36847686767578]
#
# RNN(3) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 17.5335 - mae: 2.4177 - mse: 17.5336
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 32.7722 - mae: 3.7748 - mse: 32.7725
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 81.2809 - mae: 6.1596 - mse: 81.2810
# Test Loss 8: [15.941622734069824, 2.3350136280059814, 15.953843116760254]
# Test Loss 10: [29.716516494750977, 3.4105091094970703, 29.757997512817383]
# Test Loss 14: [80.89879608154297, 6.11954927444458, 80.91987609863281]
#
# RNN_LSTM(3)
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 17.5335 - mae: 2.4177 - mse: 17.5336
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 32.7722 - mae: 3.7748 - mse: 32.7725
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 81.2809 - mae: 6.1596 - mse: 81.2810
# Test Loss 8: [15.941622734069824, 2.3350136280059814, 15.953843116760254]
# Test Loss 10: [29.716516494750977, 3.4105091094970703, 29.757997512817383]
# Test Loss 14: [80.89879608154297, 6.11954927444458, 80.91987609863281]
#
# RNN_GRU(3) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 17.8793 - mae: 2.4693 - mse: 17.8794
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 32.9915 - mae: 3.7936 - mse: 32.9918
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 81.1738 - mae: 6.0814 - mse: 81.1738
# Test Loss 8: [16.013696670532227, 2.368195056915283, 16.02600860595703]
# Test Loss 10: [29.646093368530273, 3.415783643722534, 29.687501907348633]
# Test Loss 14: [80.62100219726562, 6.018620491027832, 80.62677764892578]

# %% [markdown]
# DNN(24) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.6765 - mae: 2.1631 - mse: 13.6766
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 31.6115 - mae: 3.6212 - mse: 31.6118
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 62.1560 - mae: 5.4438 - mse: 62.1559
# Test Loss 8: [12.357009887695312, 2.082223415374756, 12.366024017333984]
# Test Loss 10: [28.87836456298828, 3.335787296295166, 28.921907424926758]
# Test Loss 14: [62.297176361083984, 5.423507213592529, 62.287109375]
# RNN(24) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.2876 - mae: 2.2766 - mse: 14.2877
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 32.1314 - mae: 3.7707 - mse: 32.1317
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 64.2471 - mae: 5.5551 - mse: 64.2469
# Test Loss 8: [12.823105812072754, 2.1927006244659424, 12.832639694213867]
# Test Loss 10: [29.04602813720703, 3.403721570968628, 29.098047256469727]
# Test Loss 14: [64.60433959960938, 5.514688014984131, 64.5594482421875]
#
# RNN_LSTM(24) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 13.5040 - mae: 2.1389 - mse: 13.5041
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 30.9619 - mae: 3.5718 - mse: 30.9622
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 60.4615 - mae: 5.3501 - mse: 60.4612
# Test Loss 8: [12.149020195007324, 2.059035539627075, 12.16039752960205]
# Test Loss 10: [27.734779357910156, 3.2240633964538574, 27.77657699584961]
# Test Loss 14: [60.43460464477539, 5.301833629608154, 60.38701248168945]
#
# RNN_GRU(24) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 13.3529 - mae: 2.1182 - mse: 13.3530
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 31.3462 - mae: 3.5849 - mse: 31.3464
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 60.4840 - mae: 5.3198 - mse: 60.4840
# Test Loss 8: [12.157280921936035, 2.042264699935913, 12.168559074401855]
# Test Loss 10: [28.2808780670166, 3.2524983882904053, 28.323163986206055]
# Test Loss 14: [60.917335510253906, 5.273698329925537, 60.908363342285156]

# %%
#Modelos para Leganés
model_leg_8, X_test_l_8, Y_test_l_8 = create_model_test(df_leg, 8, 24, 150, 32, 0.2, RNN_GRU)
model_leg_10, X_test_l_10, Y_test_l_10 = create_model_test(df_leg, 10, 24, 150, 32, 0.2, RNN_GRU)
model_leg_14, X_test_l_14, Y_test_l_14 = create_model_test(df_leg, 14, 24, 150, 32, 0.2, RNN_GRU)
# Out:
# c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - loss: 775.2774 - mae: 19.8147 - mse: 775.2769 - val_loss: 120.6328 - val_mae: 7.7055 - val_mse: 120.9210
# Epoch 2/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 28s 25ms/step - loss: 126.8440 - mae: 7.2137 - mse: 126.8441 - val_loss: 87.8257 - val_mae: 6.0062 - val_mse: 88.0808
# Epoch 3/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 32s 28ms/step - loss: 94.5079 - mae: 6.1988 - mse: 94.5080 - val_loss: 85.8410 - val_mae: 6.0255 - val_mse: 86.1088
# Epoch 4/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 50s 45ms/step - loss: 92.3328 - mae: 6.1183 - mse: 92.3328 - val_loss: 83.7089 - val_mae: 5.8092 - val_mse: 83.9295
# Epoch 5/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 49s 44ms/step - loss: 93.4108 - mae: 6.0808 - mse: 93.4107 - val_loss: 82.0133 - val_mae: 5.8112 - val_mse: 82.2734
# Epoch 6/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 49s 43ms/step - loss: 88.7234 - mae: 5.9757 - mse: 88.7235 - val_loss: 81.8541 - val_mae: 5.7458 - val_mse: 82.1032
# Epoch 7/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 44s 39ms/step - loss: 88.7709 - mae: 5.9840 - mse: 88.7710 - val_loss: 81.4915 - val_mae: 5.8176 - val_mse: 81.6992
# Epoch 8/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 36s 32ms/step - loss: 88.9397 - mae: 5.9445 - mse: 88.9396 - val_loss: 80.2020 - val_mae: 5.7135 - val_mse: 80.4463
# Epoch 9/150
#  326/1125 ━━━━━━━━━━━━━━━━━━━━ 24s 30ms/step - loss: 81.7879 - mae: 5.7874 - mse: 81.7879
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 #Modelos para Leganés
# ----> 2 model_leg_8, X_test_l_8, Y_test_l_8 = create_model_test(df_leg, 8, 24, 150, 32, 0.2, RNN_GRU)
#       3 model_leg_10, X_test_l_10, Y_test_l_10 = create_model_test(df_leg, 10, 24, 150, 32, 0.2, RNN_GRU)
#       4 model_leg_14, X_test_l_14, Y_test_l_14 = create_model_test(df_leg, 14, 24, 150, 32, 0.2, RNN_GRU)
#
# Cell In[11], line 148, in create_model_test(df, num_cont, window_size, num_epochs, b_size, val_split, mod)
#     146 def create_model_test(df, num_cont, window_size, num_epochs, b_size, val_split, mod):
#     147     X_train, X_test, Y_train, Y_test = prepara_datos(df, num_cont, window_size)
# --> 148     model = mod(window_size, X_train, Y_train, num_epochs, b_size, val_split)
#     149     return model, X_test, Y_test
#
# Cell In[11], line 140, in RNN_GRU(window_size, X_train, Y_train, num_epochs, b_size, val_split)
#     137 early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
#     139 # Entrenar el modelo
# --> 140 model.fit(X_train, Y_train, epochs=num_epochs, batch_size=b_size, validation_split=val_split, callbacks=[early_stopping])
#     142 return model
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:323, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     321 for step, iterator in epoch_iterator.enumerate_epoch():
#     322     callbacks.on_train_batch_begin(step)
# --> 323     logs = self.train_function(iterator)
#     324     callbacks.on_train_batch_end(
#     325         step, self._pythonify_logs(logs)
#     326     )
#     327     if self.stop_training:
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# Evaluar el modelo
loss_leg_8 = model_leg_8.evaluate(X_test_l_8, Y_test_l_8)
loss_leg_10 = model_leg_10.evaluate(X_test_l_10, Y_test_l_10)
loss_leg_14 = model_leg_14.evaluate(X_test_l_14, Y_test_l_14)

print(f"Test Loss 8: {loss_leg_8}")
print(f"Test Loss 10: {loss_leg_10}")
print(f"Test Loss 14: {loss_leg_14}")

# %% [markdown]
# DNN(3) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 87.8503 - mae: 6.1033 - mse: 87.8509
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.5375 - mae: 2.1055 - mse: 9.5376
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 98.5546 - mae: 6.8902 - mse: 98.5552
# Test Loss 8: [85.85559844970703, 6.003325462341309, 85.97052001953125]
# Test Loss 10: [11.199685096740723, 2.199730157852173, 11.214578628540039]
# Test Loss 14: [93.55801391601562, 6.623091697692871, 93.65955352783203]
#
# RNN(3) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 84.4450 - mae: 6.0548 - mse: 84.4456
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2260 - mae: 1.9942 - mse: 9.2260
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 96.2008 - mae: 6.7480 - mse: 96.2014
# Test Loss 8: [83.1380615234375, 5.956618785858154, 83.23963928222656]
# Test Loss 10: [10.818990707397461, 2.127671718597412, 10.833881378173828]
# Test Loss 14: [91.94145965576172, 6.490957736968994, 92.0487289428711]
#
# RNN_LSTM(3) 100 NEURONAS
# Test Loss 8: [82.63236999511719, 5.80098819732666, 82.73275756835938]
# Test Loss 10: [10.712474822998047, 2.187814712524414, 10.724699974060059]
# Test Loss 14: [91.91896057128906, 6.422314643859863, 92.03445434570312]
#
# RNN_GRU(3) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 83.2673 - mae: 5.8864 - mse: 83.2678
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.6942 - mae: 2.0205 - mse: 8.6942
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.6122 - mae: 6.8265 - mse: 96.6128
# Test Loss 8: [81.85836791992188, 5.790876388549805, 81.95953369140625]
# Test Loss 10: [10.42013931274414, 2.1558194160461426, 10.4332857131958]
# Test Loss 14: [92.05378723144531, 6.579350471496582, 92.15646362304688]

# %% [markdown]
# DNN(24) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 74.1791 - mae: 5.4793 - mse: 74.1798
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 9.2140 - mae: 2.1223 - mse: 9.2141
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 77.4415 - mae: 6.0815 - mse: 77.4419
# Test Loss 8: [71.28813934326172, 5.378331184387207, 71.40894317626953]
# Test Loss 10: [10.751276969909668, 2.2076520919799805, 10.768694877624512]
# Test Loss 14: [72.18605041503906, 5.755092620849609, 72.25773620605469]
#
# RNN(24) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 72.3800 - mae: 5.4214 - mse: 72.3806
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.6291 - mae: 2.0753 - mse: 9.6292
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 80.3437 - mae: 6.2052 - mse: 80.3440
# Test Loss 8: [71.26984405517578, 5.349955081939697, 71.37844848632812]
# Test Loss 10: [11.275654792785645, 2.226175308227539, 11.295827865600586]
# Test Loss 14: [74.7637939453125, 5.885881423950195, 74.82838439941406]
#
# RNN LSTM(24) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 68.6141 - mae: 5.2837 - mse: 68.6146
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 9.7326 - mae: 2.1620 - mse: 9.7327
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 76.6418 - mae: 5.9939 - mse: 76.6420
# Test Loss 8: [67.5677261352539, 5.2278289794921875, 67.6731948852539]
# Test Loss 10: [11.181046485900879, 2.2741992473602295, 11.199443817138672]
# Test Loss 14: [71.1746597290039, 5.678843975067139, 71.21439361572266]
#
# RNN GRU(24) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 68.5852 - mae: 5.2759 - mse: 68.5858
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.1926 - mae: 1.9813 - mse: 9.1927
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 74.9827 - mae: 5.9554 - mse: 74.9831
# Test Loss 8: [67.45165252685547, 5.209061622619629, 67.55088806152344]
# Test Loss 10: [10.786667823791504, 2.0674448013305664, 10.805265426635742]
# Test Loss 14: [70.42713165283203, 5.665657997131348, 70.50572204589844]

# %%
model_torr_8, X_test_t_8, Y_test_t_8 = create_model_test(df_torr, 8, 3, 150, 32, 0.2, RNN_GRU)
model_torr_10, X_test_t_10, Y_test_t_10 = create_model_test(df_torr, 10, 3, 150, 32, 0.2, RNN_GRU)
model_torr_14, X_test_t_14, Y_test_t_14 = create_model_test(df_torr, 14, 3, 150, 32, 0.2, RNN_GRU)
# Out:
# Epoch 1/150
# c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 362.0424 - mae: 12.5788 - mse: 362.0425 - val_loss: 64.2368 - val_mae: 5.2956 - val_mse: 64.3771
# Epoch 2/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 89.8784 - mae: 6.0894 - mse: 89.8783 - val_loss: 62.8728 - val_mae: 5.3349 - val_mse: 62.9842
# Epoch 3/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 86.0524 - mae: 5.9032 - mse: 86.0524 - val_loss: 62.8952 - val_mae: 5.3768 - val_mse: 63.0136
# Epoch 4/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 84.7746 - mae: 5.8798 - mse: 84.7746 - val_loss: 61.2552 - val_mae: 4.9844 - val_mse: 61.3678
# Epoch 5/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 82.3364 - mae: 5.8431 - mse: 82.3364 - val_loss: 58.2315 - val_mae: 4.8985 - val_mse: 58.3365
# Epoch 6/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 82.5027 - mae: 5.8429 - mse: 82.5027 - val_loss: 57.4778 - val_mae: 4.8269 - val_mse: 57.5892
# Epoch 7/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 82.2822 - mae: 5.8122 - mse: 82.2822 - val_loss: 59.0270 - val_mae: 5.0047 - val_mse: 59.1287
# Epoch 8/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 83.6074 - mae: 5.8235 - mse: 83.6074 - val_loss: 57.7048 - val_mae: 4.8724 - val_mse: 57.8068
# Epoch 9/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 82.3469 - mae: 5.8101 - mse: 82.3469 - val_loss: 57.5046 - val_mae: 4.8142 - val_mse: 57.6101
# Epoch 10/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 81.2095 - mae: 5.7809 - mse: 81.2095 - val_loss: 58.4849 - val_mae: 4.9183 - val_mse: 58.5852
# Epoch 11/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 79.9975 - mae: 5.7334 - mse: 79.9974 - val_loss: 57.8317 - val_mae: 4.8196 - val_mse: 57.9458
# Epoch 12/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 79.8995 - mae: 5.7380 - mse: 79.8995 - val_loss: 57.4127 - val_mae: 4.9172 - val_mse: 57.5142
# Epoch 13/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 79.2956 - mae: 5.6831 - mse: 79.2956 - val_loss: 57.3157 - val_mae: 4.8791 - val_mse: 57.4192
# Epoch 14/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 82.1995 - mae: 5.7793 - mse: 82.1995 - val_loss: 59.9262 - val_mae: 5.0762 - val_mse: 60.0191
# Epoch 15/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 80.2787 - mae: 5.7328 - mse: 80.2787 - val_loss: 61.2067 - val_mae: 5.0853 - val_mse: 61.2996
# Epoch 16/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 80.6376 - mae: 5.7660 - mse: 80.6376 - val_loss: 57.5768 - val_mae: 4.8908 - val_mse: 57.6754
# Epoch 17/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 80.9189 - mae: 5.7734 - mse: 80.9189 - val_loss: 57.5347 - val_mae: 4.9503 - val_mse: 57.6399
# Epoch 18/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 79.9937 - mae: 5.7301 - mse: 79.9937 - val_loss: 58.0104 - val_mae: 4.8726 - val_mse: 58.1173
# Epoch 19/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 82.1443 - mae: 5.7548 - mse: 82.1443 - val_loss: 57.9681 - val_mae: 4.9984 - val_mse: 58.0646
# Epoch 20/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 82.5855 - mae: 5.8025 - mse: 82.5855 - val_loss: 58.2295 - val_mae: 4.8492 - val_mse: 58.3388
# Epoch 21/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 78.2097 - mae: 5.6496 - mse: 78.2098 - val_loss: 57.9000 - val_mae: 4.9209 - val_mse: 57.9973
# Epoch 22/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 81.9856 - mae: 5.7806 - mse: 81.9856 - val_loss: 58.1049 - val_mae: 4.8802 - val_mse: 58.2028
# Epoch 23/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 78.0031 - mae: 5.6881 - mse: 78.0029 - val_loss: 58.5352 - val_mae: 4.9157 - val_mse: 58.6400
# Epoch 1/150
# c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 266.3300 - mae: 9.4606 - mse: 266.3301 - val_loss: 266.4918 - val_mae: 4.1022 - val_mse: 267.2866
# Epoch 2/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 58.4199 - mae: 4.2195 - mse: 58.4199 - val_loss: 213.9032 - val_mae: 3.7086 - val_mse: 214.5404
# Epoch 3/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 46.7243 - mae: 3.9903 - mse: 46.7244 - val_loss: 185.0204 - val_mae: 3.5653 - val_mse: 185.5713
# Epoch 4/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 46.5378 - mae: 4.0058 - mse: 46.5378 - val_loss: 165.4843 - val_mae: 3.5851 - val_mse: 165.9769
# Epoch 5/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 46.5499 - mae: 3.9961 - mse: 46.5499 - val_loss: 148.5950 - val_mae: 3.4873 - val_mse: 149.0360
# Epoch 6/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 49.0332 - mae: 3.9712 - mse: 49.0332 - val_loss: 134.4849 - val_mae: 3.3980 - val_mse: 134.8831
# Epoch 7/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 42.8403 - mae: 3.9307 - mse: 42.8403 - val_loss: 123.7844 - val_mae: 3.3269 - val_mse: 124.1500
# Epoch 8/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 46.1912 - mae: 3.9281 - mse: 46.1912 - val_loss: 117.6861 - val_mae: 3.3012 - val_mse: 118.0335
# Epoch 9/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 41.6930 - mae: 3.9116 - mse: 41.6930 - val_loss: 108.6029 - val_mae: 3.2904 - val_mse: 108.9240
# Epoch 10/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 40.1816 - mae: 3.8981 - mse: 40.1816 - val_loss: 102.4907 - val_mae: 3.2832 - val_mse: 102.7917
# Epoch 11/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 40.6960 - mae: 3.8614 - mse: 40.6960 - val_loss: 96.4541 - val_mae: 3.2293 - val_mse: 96.7373
# Epoch 12/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 39.3975 - mae: 3.8663 - mse: 39.3975 - val_loss: 91.1713 - val_mae: 3.0968 - val_mse: 91.4391
# Epoch 13/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 40.4454 - mae: 3.8861 - mse: 40.4454 - val_loss: 88.1548 - val_mae: 3.2216 - val_mse: 88.4130
# Epoch 14/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 38.7475 - mae: 3.8605 - mse: 38.7475 - val_loss: 83.6004 - val_mae: 3.1958 - val_mse: 83.8450
# Epoch 15/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 39.2229 - mae: 3.8608 - mse: 39.2228 - val_loss: 80.4115 - val_mae: 3.0797 - val_mse: 80.6478
# Epoch 16/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 40.2666 - mae: 3.8903 - mse: 40.2666 - val_loss: 77.9445 - val_mae: 3.0972 - val_mse: 78.1725
# Epoch 17/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 39.6941 - mae: 3.8602 - mse: 39.6942 - val_loss: 73.7490 - val_mae: 3.1050 - val_mse: 73.9637
# Epoch 18/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 39.2712 - mae: 3.8643 - mse: 39.2712 - val_loss: 71.2062 - val_mae: 3.0299 - val_mse: 71.4146
# Epoch 19/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 39.7556 - mae: 3.8645 - mse: 39.7556 - val_loss: 70.3119 - val_mae: 3.0572 - val_mse: 70.5173
# Epoch 20/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 41.1041 - mae: 3.8917 - mse: 41.1041 - val_loss: 67.1052 - val_mae: 3.1108 - val_mse: 67.2998
# Epoch 21/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 38.8958 - mae: 3.8393 - mse: 38.8958 - val_loss: 68.0088 - val_mae: 3.0959 - val_mse: 68.2075
# Epoch 22/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 39.2527 - mae: 3.8439 - mse: 39.2526 - val_loss: 63.3578 - val_mae: 3.0564 - val_mse: 63.5417
# Epoch 23/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 39.4290 - mae: 3.8276 - mse: 39.4290 - val_loss: 61.7994 - val_mae: 2.9879 - val_mse: 61.9793
# Epoch 24/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 38.9605 - mae: 3.8394 - mse: 38.9605 - val_loss: 61.4322 - val_mae: 3.0409 - val_mse: 61.6113
# Epoch 25/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 39.3698 - mae: 3.8358 - mse: 39.3698 - val_loss: 60.2568 - val_mae: 3.0961 - val_mse: 60.4314
# Epoch 26/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 39.5310 - mae: 3.8637 - mse: 39.5310 - val_loss: 62.6470 - val_mae: 3.0632 - val_mse: 62.8295
# Epoch 27/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 36.7934 - mae: 3.8244 - mse: 36.7934 - val_loss: 57.0328 - val_mae: 3.0077 - val_mse: 57.1986
# Epoch 28/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 39.1556 - mae: 3.8334 - mse: 39.1556 - val_loss: 56.4384 - val_mae: 2.9889 - val_mse: 56.6022
# Epoch 29/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 37.6639 - mae: 3.8024 - mse: 37.6639 - val_loss: 53.9885 - val_mae: 3.0567 - val_mse: 54.1418
# Epoch 30/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 37.0231 - mae: 3.7839 - mse: 37.0231 - val_loss: 58.8650 - val_mae: 3.0528 - val_mse: 59.0364
# Epoch 31/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 36.3924 - mae: 3.7726 - mse: 36.3924 - val_loss: 54.6955 - val_mae: 3.0986 - val_mse: 54.8514
# Epoch 32/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 39.9287 - mae: 3.8652 - mse: 39.9287 - val_loss: 51.7357 - val_mae: 2.9648 - val_mse: 51.8853
# Epoch 33/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 38.3002 - mae: 3.8244 - mse: 38.3002 - val_loss: 52.0816 - val_mae: 2.9499 - val_mse: 52.2321
# Epoch 34/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 36.7189 - mae: 3.8190 - mse: 36.7189 - val_loss: 50.4620 - val_mae: 3.0247 - val_mse: 50.6062
# Epoch 35/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 38.0121 - mae: 3.8048 - mse: 38.0121 - val_loss: 47.9880 - val_mae: 2.9334 - val_mse: 48.1261
# Epoch 36/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 39.9865 - mae: 3.8370 - mse: 39.9865 - val_loss: 47.5520 - val_mae: 2.9175 - val_mse: 47.6889
# Epoch 37/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 37.5605 - mae: 3.8006 - mse: 37.5606 - val_loss: 47.2910 - val_mae: 2.9619 - val_mse: 47.4271
# Epoch 38/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 41.6184 - mae: 3.8822 - mse: 41.6184 - val_loss: 52.2568 - val_mae: 2.9872 - val_mse: 52.4070
# Epoch 39/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 40.0014 - mae: 3.8095 - mse: 40.0014 - val_loss: 47.8694 - val_mae: 2.9160 - val_mse: 48.0074
# Epoch 40/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 39.4753 - mae: 3.8609 - mse: 39.4753 - val_loss: 45.2497 - val_mae: 2.8714 - val_mse: 45.3789
# Epoch 41/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 36.6886 - mae: 3.7994 - mse: 36.6886 - val_loss: 49.3460 - val_mae: 3.0412 - val_mse: 49.4882
# Epoch 42/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 37.4873 - mae: 3.7915 - mse: 37.4873 - val_loss: 44.8828 - val_mae: 2.8799 - val_mse: 45.0117
# Epoch 43/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 38.5840 - mae: 3.7939 - mse: 38.5841 - val_loss: 44.6587 - val_mae: 2.8869 - val_mse: 44.7874
# Epoch 44/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 40.0122 - mae: 3.8518 - mse: 40.0122 - val_loss: 49.7590 - val_mae: 2.9670 - val_mse: 49.9022
# Epoch 45/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 37.7862 - mae: 3.8429 - mse: 37.7862 - val_loss: 42.7879 - val_mae: 2.9106 - val_mse: 42.9097
# Epoch 46/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 41.7071 - mae: 3.8923 - mse: 41.7071 - val_loss: 45.1832 - val_mae: 3.0057 - val_mse: 45.3115
# Epoch 47/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 37.2319 - mae: 3.7988 - mse: 37.2319 - val_loss: 43.8300 - val_mae: 3.0360 - val_mse: 43.9542
# Epoch 48/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 35.4826 - mae: 3.7560 - mse: 35.4826 - val_loss: 44.5011 - val_mae: 2.9011 - val_mse: 44.6287
# Epoch 49/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 37.5222 - mae: 3.8025 - mse: 37.5222 - val_loss: 41.5311 - val_mae: 2.9967 - val_mse: 41.6485
# Epoch 50/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 36.8046 - mae: 3.8073 - mse: 36.8046 - val_loss: 41.1059 - val_mae: 2.8537 - val_mse: 41.2226
# Epoch 51/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 39.7763 - mae: 3.8216 - mse: 39.7763 - val_loss: 51.6482 - val_mae: 2.9970 - val_mse: 51.7969
# Epoch 52/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 39.2567 - mae: 3.7917 - mse: 39.2567 - val_loss: 46.1192 - val_mae: 2.9788 - val_mse: 46.2513
# Epoch 53/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 37.8029 - mae: 3.7867 - mse: 37.8029 - val_loss: 42.0375 - val_mae: 2.9090 - val_mse: 42.1578
# Epoch 54/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 37.2699 - mae: 3.7835 - mse: 37.2699 - val_loss: 45.8132 - val_mae: 2.9221 - val_mse: 45.9440
# Epoch 55/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 36.2818 - mae: 3.7527 - mse: 36.2818 - val_loss: 41.9866 - val_mae: 2.8788 - val_mse: 42.1063
# Epoch 56/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 36.9450 - mae: 3.7818 - mse: 36.9450 - val_loss: 40.7280 - val_mae: 2.9168 - val_mse: 40.8443
# Epoch 57/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 36.4645 - mae: 3.7938 - mse: 36.4645 - val_loss: 39.7698 - val_mae: 2.8765 - val_mse: 39.8829
# Epoch 58/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 37.8089 - mae: 3.8183 - mse: 37.8089 - val_loss: 44.8211 - val_mae: 2.9222 - val_mse: 44.9496
# Epoch 59/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 37.8235 - mae: 3.7856 - mse: 37.8235 - val_loss: 43.1096 - val_mae: 2.9728 - val_mse: 43.2325
# Epoch 60/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 37.6328 - mae: 3.7978 - mse: 37.6328 - val_loss: 43.9171 - val_mae: 2.9849 - val_mse: 44.0430
# Epoch 61/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 36.9493 - mae: 3.7671 - mse: 36.9493 - val_loss: 38.5245 - val_mae: 2.8640 - val_mse: 38.6341
# Epoch 62/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 36.1471 - mae: 3.7764 - mse: 36.1471 - val_loss: 43.8720 - val_mae: 2.9393 - val_mse: 43.9968
# Epoch 63/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 37.8555 - mae: 3.8184 - mse: 37.8555 - val_loss: 40.2291 - val_mae: 2.8825 - val_mse: 40.3434
# Epoch 64/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 40.4774 - mae: 3.8299 - mse: 40.4774 - val_loss: 41.4630 - val_mae: 2.9680 - val_mse: 41.5822
# Epoch 65/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 37.6481 - mae: 3.7893 - mse: 37.6481 - val_loss: 40.5661 - val_mae: 2.9105 - val_mse: 40.6813
# Epoch 66/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 36.3928 - mae: 3.7546 - mse: 36.3928 - val_loss: 41.0604 - val_mae: 2.9128 - val_mse: 41.1779
# Epoch 67/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 36.2318 - mae: 3.7631 - mse: 36.2318 - val_loss: 39.3948 - val_mae: 2.8796 - val_mse: 39.5065
# Epoch 68/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 36.5001 - mae: 3.7707 - mse: 36.5001 - val_loss: 42.5847 - val_mae: 2.9237 - val_mse: 42.7062
# Epoch 69/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 38.4461 - mae: 3.7850 - mse: 38.4461 - val_loss: 37.3735 - val_mae: 2.8265 - val_mse: 37.4795
# Epoch 70/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 37.7428 - mae: 3.8002 - mse: 37.7428 - val_loss: 44.1076 - val_mae: 2.9832 - val_mse: 44.2341
# Epoch 71/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 36.7455 - mae: 3.7549 - mse: 36.7454 - val_loss: 39.8413 - val_mae: 2.8765 - val_mse: 39.9541
# Epoch 72/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 39.2765 - mae: 3.8002 - mse: 39.2764 - val_loss: 39.4373 - val_mae: 2.9184 - val_mse: 39.5501
# Epoch 73/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 37.8179 - mae: 3.8085 - mse: 37.8179 - val_loss: 46.8446 - val_mae: 2.9262 - val_mse: 46.9786
# Epoch 74/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 37.5296 - mae: 3.7875 - mse: 37.5296 - val_loss: 41.1382 - val_mae: 3.0267 - val_mse: 41.2532
# Epoch 75/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 36.6892 - mae: 3.7755 - mse: 36.6893 - val_loss: 39.4591 - val_mae: 2.8670 - val_mse: 39.5708
# Epoch 76/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 38.9845 - mae: 3.8305 - mse: 38.9845 - val_loss: 37.9768 - val_mae: 2.9204 - val_mse: 38.0843
# Epoch 77/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 36.3302 - mae: 3.7590 - mse: 36.3302 - val_loss: 41.4192 - val_mae: 3.1059 - val_mse: 41.5344
# Epoch 78/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 39.9130 - mae: 3.8536 - mse: 39.9130 - val_loss: 41.4824 - val_mae: 2.8870 - val_mse: 41.6006
# Epoch 79/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 36.0187 - mae: 3.7577 - mse: 36.0188 - val_loss: 40.6707 - val_mae: 2.9035 - val_mse: 40.7868
# Epoch 1/150
# c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1544.3236 - mae: 28.8114 - mse: 1544.3240 - val_loss: 242.6927 - val_mae: 11.4945 - val_mse: 243.2702
# Epoch 2/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 180.1365 - mae: 9.6472 - mse: 180.1365 - val_loss: 133.7326 - val_mae: 7.8090 - val_mse: 134.0039
# Epoch 3/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 117.6894 - mae: 7.5797 - mse: 117.6894 - val_loss: 114.9959 - val_mae: 7.5035 - val_mse: 115.1930
# Epoch 4/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 111.4483 - mae: 7.2945 - mse: 111.4483 - val_loss: 109.5472 - val_mae: 7.2079 - val_mse: 109.7197
# Epoch 5/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 107.3435 - mae: 7.1797 - mse: 107.3436 - val_loss: 106.6800 - val_mae: 7.0369 - val_mse: 106.8427
# Epoch 6/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 106.9825 - mae: 7.1792 - mse: 106.9824 - val_loss: 107.3279 - val_mae: 7.1962 - val_mse: 107.4950
# Epoch 7/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 108.0100 - mae: 7.1751 - mse: 108.0100 - val_loss: 105.8087 - val_mae: 6.9909 - val_mse: 105.9836
# Epoch 8/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 105.9366 - mae: 7.1155 - mse: 105.9366 - val_loss: 103.4615 - val_mae: 7.0533 - val_mse: 103.6258
# Epoch 9/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 102.9363 - mae: 7.0502 - mse: 102.9363 - val_loss: 105.0461 - val_mae: 6.9994 - val_mse: 105.2220
# Epoch 10/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 104.0876 - mae: 7.0417 - mse: 104.0876 - val_loss: 104.6091 - val_mae: 7.0288 - val_mse: 104.7648
# Epoch 11/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 103.9661 - mae: 7.0501 - mse: 103.9660 - val_loss: 104.0179 - val_mae: 7.0745 - val_mse: 104.1714
# Epoch 12/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 103.2438 - mae: 7.0459 - mse: 103.2438 - val_loss: 102.6940 - val_mae: 6.8763 - val_mse: 102.8541
# Epoch 13/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 102.2350 - mae: 6.9952 - mse: 102.2351 - val_loss: 102.8892 - val_mae: 6.9434 - val_mse: 103.0565
# Epoch 14/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 104.1187 - mae: 7.0541 - mse: 104.1187 - val_loss: 103.4558 - val_mae: 7.1085 - val_mse: 103.6267
# Epoch 15/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 103.5824 - mae: 7.0296 - mse: 103.5824 - val_loss: 101.7776 - val_mae: 6.8528 - val_mse: 101.9422
# Epoch 16/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 102.1833 - mae: 7.0225 - mse: 102.1831 - val_loss: 101.5976 - val_mae: 6.8612 - val_mse: 101.7598
# Epoch 17/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 101.6938 - mae: 7.0192 - mse: 101.6938 - val_loss: 102.0321 - val_mae: 6.8844 - val_mse: 102.1857
# Epoch 18/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 102.2177 - mae: 7.0012 - mse: 102.2178 - val_loss: 102.7638 - val_mae: 7.0147 - val_mse: 102.9174
# Epoch 19/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 101.6240 - mae: 6.9779 - mse: 101.6240 - val_loss: 101.3709 - val_mae: 6.9913 - val_mse: 101.5269
# Epoch 20/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 102.0957 - mae: 6.9946 - mse: 102.0956 - val_loss: 100.7397 - val_mae: 6.8742 - val_mse: 100.8986
# Epoch 21/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 101.8018 - mae: 6.9832 - mse: 101.8019 - val_loss: 102.5669 - val_mae: 6.9959 - val_mse: 102.7419
# Epoch 22/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 101.0550 - mae: 6.9271 - mse: 101.0550 - val_loss: 102.8131 - val_mae: 6.9292 - val_mse: 102.9785
# Epoch 23/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 102.6411 - mae: 6.9806 - mse: 102.6411 - val_loss: 102.5767 - val_mae: 6.9580 - val_mse: 102.7316
# Epoch 24/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 101.2143 - mae: 6.9554 - mse: 101.2143 - val_loss: 101.2866 - val_mae: 6.9125 - val_mse: 101.4456
# Epoch 25/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 102.0137 - mae: 6.9631 - mse: 102.0137 - val_loss: 101.9719 - val_mae: 7.0096 - val_mse: 102.1360
# Epoch 26/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 103.2180 - mae: 7.0023 - mse: 103.2179 - val_loss: 104.5283 - val_mae: 7.1409 - val_mse: 104.6914
# Epoch 27/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 100.2203 - mae: 6.9505 - mse: 100.2202 - val_loss: 100.9726 - val_mae: 6.8726 - val_mse: 101.1313
# Epoch 28/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 104.6633 - mae: 7.0787 - mse: 104.6633 - val_loss: 101.3387 - val_mae: 6.9419 - val_mse: 101.4970
# Epoch 29/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 101.1664 - mae: 6.9487 - mse: 101.1665 - val_loss: 100.5345 - val_mae: 6.8477 - val_mse: 100.6995
# Epoch 30/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 102.5733 - mae: 6.9798 - mse: 102.5733 - val_loss: 101.3828 - val_mae: 6.8366 - val_mse: 101.5514
# Epoch 31/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 102.7424 - mae: 6.9677 - mse: 102.7424 - val_loss: 100.7586 - val_mae: 6.9041 - val_mse: 100.9279
# Epoch 32/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 101.6467 - mae: 6.9947 - mse: 101.6467 - val_loss: 101.1737 - val_mae: 6.9904 - val_mse: 101.3376
# Epoch 33/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 101.7289 - mae: 6.9774 - mse: 101.7289 - val_loss: 100.2797 - val_mae: 6.8970 - val_mse: 100.4476
# Epoch 34/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 103.0093 - mae: 7.0225 - mse: 103.0093 - val_loss: 100.8108 - val_mae: 6.8644 - val_mse: 100.9706
# Epoch 35/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 103.3675 - mae: 7.0214 - mse: 103.3675 - val_loss: 100.2649 - val_mae: 6.8019 - val_mse: 100.4312
# Epoch 36/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 101.7857 - mae: 6.9940 - mse: 101.7857 - val_loss: 102.8242 - val_mae: 7.1288 - val_mse: 102.9870
# Epoch 37/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 101.3221 - mae: 6.9553 - mse: 101.3220 - val_loss: 102.1872 - val_mae: 6.9711 - val_mse: 102.3426
# Epoch 38/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 101.3250 - mae: 6.9272 - mse: 101.3250 - val_loss: 100.9753 - val_mae: 6.8597 - val_mse: 101.1326
# Epoch 39/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 101.1579 - mae: 6.9473 - mse: 101.1579 - val_loss: 100.2218 - val_mae: 6.8151 - val_mse: 100.3794
# Epoch 40/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 99.4711 - mae: 6.9003 - mse: 99.4711 - val_loss: 101.0039 - val_mae: 6.9017 - val_mse: 101.1702
# Epoch 41/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 101.3140 - mae: 6.9455 - mse: 101.3140 - val_loss: 102.5279 - val_mae: 6.8921 - val_mse: 102.6923
# Epoch 42/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 100.0609 - mae: 6.8743 - mse: 100.0609 - val_loss: 99.9921 - val_mae: 6.8321 - val_mse: 100.1541
# Epoch 43/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 100.6844 - mae: 6.9201 - mse: 100.6844 - val_loss: 100.3678 - val_mae: 6.8423 - val_mse: 100.5307
# Epoch 44/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 100.7531 - mae: 6.9266 - mse: 100.7531 - val_loss: 100.9111 - val_mae: 7.0468 - val_mse: 101.0730
# Epoch 45/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 98.7757 - mae: 6.8877 - mse: 98.7757 - val_loss: 100.5054 - val_mae: 6.9110 - val_mse: 100.6682
# Epoch 46/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 103.1984 - mae: 7.0060 - mse: 103.1985 - val_loss: 100.5787 - val_mae: 6.8903 - val_mse: 100.7424
# Epoch 47/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 97.5691 - mae: 6.8336 - mse: 97.5691 - val_loss: 99.9768 - val_mae: 6.8108 - val_mse: 100.1299
# Epoch 48/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 101.6254 - mae: 6.9369 - mse: 101.6254 - val_loss: 99.4560 - val_mae: 6.8126 - val_mse: 99.6133
# Epoch 49/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 101.4087 - mae: 6.9357 - mse: 101.4088 - val_loss: 100.0982 - val_mae: 6.8899 - val_mse: 100.2678
# Epoch 50/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 102.2666 - mae: 6.9888 - mse: 102.2666 - val_loss: 100.4375 - val_mae: 6.9360 - val_mse: 100.6031
# Epoch 51/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 101.9126 - mae: 6.9745 - mse: 101.9127 - val_loss: 99.2584 - val_mae: 6.8693 - val_mse: 99.4180
# Epoch 52/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 100.3694 - mae: 6.8902 - mse: 100.3693 - val_loss: 99.4869 - val_mae: 6.7749 - val_mse: 99.6474
# Epoch 53/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 99.3444 - mae: 6.8513 - mse: 99.3444 - val_loss: 100.4943 - val_mae: 6.8688 - val_mse: 100.6571
# Epoch 54/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 100.7470 - mae: 6.9015 - mse: 100.7470 - val_loss: 100.0018 - val_mae: 6.8724 - val_mse: 100.1649
# Epoch 55/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 99.4232 - mae: 6.8587 - mse: 99.4232 - val_loss: 100.8095 - val_mae: 6.8992 - val_mse: 100.9687
# Epoch 56/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 102.4435 - mae: 6.9620 - mse: 102.4435 - val_loss: 100.0041 - val_mae: 6.9008 - val_mse: 100.1627
# Epoch 57/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 101.4624 - mae: 6.9702 - mse: 101.4624 - val_loss: 100.2172 - val_mae: 6.8924 - val_mse: 100.3802
# Epoch 58/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 99.5939 - mae: 6.8533 - mse: 99.5939 - val_loss: 100.1324 - val_mae: 6.7903 - val_mse: 100.2929
# Epoch 59/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 100.1378 - mae: 6.9025 - mse: 100.1379 - val_loss: 99.4633 - val_mae: 6.8335 - val_mse: 99.6256
# Epoch 60/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 98.8754 - mae: 6.8789 - mse: 98.8754 - val_loss: 99.9685 - val_mae: 6.9012 - val_mse: 100.1253
# Epoch 61/150
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 100.2171 - mae: 6.9167 - mse: 100.2171 - val_loss: 99.8969 - val_mae: 6.7983 - val_mse: 100.0606

# %%
# Evaluar el modelo de Torrejón de Ardoz
loss_torr_8 = model_torr_8.evaluate(X_test_t_8, Y_test_t_8)
loss_torr_10 = model_torr_10.evaluate(X_test_t_10, Y_test_t_10)
loss_torr_14 = model_torr_14.evaluate(X_test_t_14, Y_test_t_14)

print(f"Test Loss 8: {loss_torr_8}")
print(f"Test Loss 10: {loss_torr_10}")
print(f"Test Loss 14: {loss_torr_14}")
# Out:
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 55.5360 - mae: 4.8511 - mse: 55.5364
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 10.3134 - mae: 2.0867 - mse: 10.3134
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 102.5066 - mae: 7.1085 - mse: 102.5072
# Test Loss 8: [54.13479995727539, 4.743683338165283, 54.21220397949219]
# Test Loss 10: [12.571667671203613, 2.2789418697357178, 12.576087951660156]
# Test Loss 14: [100.908935546875, 6.939528465270996, 101.01778411865234]

# %% [markdown]
# DNN(3) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 56.1179 - mae: 4.9991 - mse: 56.1183
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.6800 - mae: 2.1519 - mse: 10.6801
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 103.1506 - mae: 7.0816 - mse: 103.1513
# Test Loss 8: [54.84965515136719, 4.8891072273254395, 54.92226028442383]
# Test Loss 10: [13.24984359741211, 2.3559491634368896, 13.256821632385254]
# Test Loss 14: [102.01081848144531, 6.936549186706543, 102.12812042236328]
#
# RNN(3) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 55.3705 - mae: 4.7789 - mse: 55.3709
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 11.1657 - mae: 2.2042 - mse: 11.1657
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 105.2840 - mae: 7.1227 - mse: 105.2846
# Test Loss 8: [54.3084602355957, 4.694724082946777, 54.38799285888672]
# Test Loss 10: [13.596179008483887, 2.4060778617858887, 13.600802421569824]
# Test Loss 14: [103.51685333251953, 6.912387371063232, 103.62413024902344]
#
# RNN_LSTM(3) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 55.5497 - mae: 4.8576 - mse: 55.5501
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 10.4711 - mae: 2.1558 - mse: 10.4711
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 102.3260 - mae: 7.0563 - mse: 102.3266
# Test Loss 8: [54.50950622558594, 4.773031234741211, 54.58770751953125]
# Test Loss 10: [12.471543312072754, 2.346558094024658, 12.475689888000488]
# Test Loss 14: [100.47252655029297, 6.872214317321777, 100.58133697509766]
#
# RNN_GRU(3) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 55.5360 - mae: 4.8511 - mse: 55.5364
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 10.3134 - mae: 2.0867 - mse: 10.3134
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 102.5066 - mae: 7.1085 - mse: 102.5072
# Test Loss 8: [54.13479995727539, 4.743683338165283, 54.21220397949219]
# Test Loss 10: [12.571667671203613, 2.2789418697357178, 12.576087951660156]
# Test Loss 14: [100.908935546875, 6.939528465270996, 101.01778411865234]

# %% [markdown]
# DNN(24) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 46.8733 - mae: 4.4899 - mse: 46.8738
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11.6911 - mae: 2.2091 - mse: 11.6912
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 80.1706 - mae: 6.2418 - mse: 80.1712
# Test Loss 8: [45.14418411254883, 4.38491153717041, 45.226173400878906]
# Test Loss 10: [14.5762300491333, 2.415510654449463, 14.587716102600098]
# Test Loss 14: [80.30597686767578, 6.1107635498046875, 80.40937805175781]
#
# RNN(24) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 49.0125 - mae: 4.6365 - mse: 49.0130
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 10.7811 - mae: 2.2068 - mse: 10.7811
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 83.9717 - mae: 6.4183 - mse: 83.9723
# Test Loss 8: [47.358585357666016, 4.535187721252441, 47.444766998291016]
# Test Loss 10: [14.232047080993652, 2.4143712520599365, 14.23529052734375]
# Test Loss 14: [84.53557586669922, 6.31210994720459, 84.63433074951172]
#
# RNN_LSTM(24) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 46.2405 - mae: 4.3991 - mse: 46.2410
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 10.6551 - mae: 2.1518 - mse: 10.6551
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 77.4127 - mae: 6.1251 - mse: 77.4132
# Test Loss 8: [44.84203338623047, 4.306980133056641, 44.92310333251953]
# Test Loss 10: [14.043763160705566, 2.359495162963867, 14.050171852111816]
# Test Loss 14: [76.79094696044922, 5.938340663909912, 76.88684844970703]
#
# RNN_GRU(24) 100 NEURONAS
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 46.8854 - mae: 4.4627 - mse: 46.8859
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 11.7083 - mae: 2.2875 - mse: 11.7083
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 77.8711 - mae: 6.1716 - mse: 77.8717
# Test Loss 8: [45.37168884277344, 4.358640670776367, 45.4550666809082]
# Test Loss 10: [15.068100929260254, 2.45654296875, 15.077798843383789]
# Test Loss 14: [77.44457244873047, 5.997723579406738, 77.54349517822266]

# %%
# Gáfica de la predicción 
def prediction_plot(df, cont, test_predict, window_size, title):
    #x_prediction=df.tail(len(test_predict))[train_size:].index[window_size:] 
    x_prediction=df.tail(len(test_predict)).index
    plt.figure(figsize=(12,6))
    plt.plot(df.index, df[cont], label="Observado")
    plt.plot(x_prediction, test_predict, color='orange', label="Predicción")
    plt.tight_layout()
    sns.despine(top=True)
    plt.subplots_adjust(left=0.07)
    plt.ylabel('Dato', size=15)
    plt.xlabel('Fecha', size=15)
    plt.title(title)
    plt.legend(fontsize=15)
    plt.show();

# %%
# Hacer predicciones
p_l_8 = model_leg_8.predict(X_test_l_8)
p_l_10 = model_leg_10.predict(X_test_l_10)
p_l_14 = model_leg_14.predict(X_test_l_14)

prediction_plot(df_leg, '8', p_l_8, 24,'Predicción de concentración de NO2 en la estación 74,7')
prediction_plot(df_leg, '10', p_l_10, 24,'Predicción de concentración de PM < 10 en la estación 74,7')
prediction_plot(df_leg, '14', p_l_14, 24,'Predicción de concentración de Ozono en la estación 74,7')

# %%
#Función que predice n_pred valores dados k valores previos 
def predecir_(model, X_previos, n_pred):
    for i in range(n_pred):
        pred = model.predict(np.array(X_previos[i,:]))
        X_previos = np.append(X_previos, pred)
    return X_previos
